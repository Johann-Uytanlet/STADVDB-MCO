# %% [markdown]
# # MCO1

# %% [markdown]
# ### Import CSV Files and Read Data

# %%
import pandas as pd 
import numpy as np
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine

appointments_path = 'appointments.csv'
clinics_path = 'clinics.csv'
doctors_path = 'doctors.csv'
px_path = 'px.csv' # patients

# %%
appointments = pd.read_csv(appointments_path)

# %%
clinics = pd.read_csv(clinics_path, encoding='ISO-8859-1')

# %%
doctors = pd.read_csv(doctors_path, encoding='ISO-8859-1')

# %%
px = pd.read_csv(px_path, encoding='ISO-8859-1', low_memory=False)

# %% [markdown]
# ### Check the columns/variables of each table

# %%
print(appointments.columns)
print(clinics.columns)
print(doctors.columns)
print(px.columns)
# Out:
# Index(['pxid', 'clinicid', 'doctorid', 'apptid', 'status', 'TimeQueued',
#        'QueueDate', 'StartTime', 'EndTime', 'type', 'Virtual'],
#       dtype='object')
# Index(['clinicid', 'hospitalname', 'IsHospital', 'City', 'Province',
#        'RegionName'],
#       dtype='object')
# Index(['doctorid', 'mainspecialty', 'age'], dtype='object')
# Index(['pxid', 'age', 'gender'], dtype='object')

# %% [markdown]
# ### Check the number of rows and columns of each our csv files using .shape and check if there are null values in each variables

# %%
# Clinics Row and Column
print('clinic shape', clinics.shape)
clinics.info()


# Doctors Row and Column
print('\ndoctors shape', doctors.shape)
doctors.info()

# Px Row and Column
print('\npx shape', px.shape)
px.info()

# Appointments Row and Column
print('\nappointments shape', appointments.shape)
appointments.info()
# Out:
# clinic shape (53962, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53962 entries, 0 to 53961
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   clinicid      53962 non-null  object
#  1   hospitalname  17538 non-null  object
#  2   IsHospital    53962 non-null  bool
#  3   City          53962 non-null  object
#  4   Province      53962 non-null  object
#  5   RegionName    53962 non-null  object
# dtypes: bool(1), object(5)
# memory usage: 2.1+ MB
#
# doctors shape (60024, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60024 entries, 0 to 60023
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   doctorid       60024 non-null  object
#  1   mainspecialty  27175 non-null  object
#  2   age            20028 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.4+ MB
#
# px shape (6507813, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6507813 entries, 0 to 6507812
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   pxid    object
#  1   age     object
#  2   gender  object
# dtypes: object(3)
# memory usage: 149.0+ MB
#
# appointments shape (9752932, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9752932 entries, 0 to 9752931
# Data columns (total 11 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   pxid        object
#  1   clinicid    object
#  2   doctorid    object
#  3   apptid      object
#  4   status      object
#  5   TimeQueued  object
#  6   QueueDate   object
#  7   StartTime   object
#  8   EndTime     object
#  9   type        object
#  10  Virtual     object
# dtypes: object(11)
# memory usage: 818.5+ MB

# %% [markdown]
# Since we are using Star Schema, we remove appointments that are not in dimension tables
#
# - appointment table = Fact Table
# - doctors = Dimension Table
# - clinics = Dimension Table
# - px = Dimension Table

# %%
# remove appointments that are not in pxid table
print(appointments.shape)
appointments = appointments[appointments['pxid'].isin(px['pxid'])]

# remove appointments that are not in the clinics table
print(appointments.shape)
appointments = appointments[appointments['clinicid'].isin(clinics['clinicid'])]
print(appointments.shape)

# remove appointments that are not in the doctors table
print(appointments.shape)
appointments = appointments[appointments['doctorid'].isin(doctors['doctorid'])]
print(appointments.shape)
# Out:
# (9752932, 11)
# (320140, 11)
# (320140, 11)
# (320140, 11)
# (320140, 11)

# %%
uniq_val = doctors['mainspecialty'].unique()

for elem in uniq_val:
    print(elem)
# Out:
# General Medicine
# Family Medicine
# Vascular Medicine
# Otolaryngologists
# General Dentistry
# Orthopedic
# Acupunturist1
# Orthopaedic Sports Medicine
# Masters of Science in Preventive & Regenerative Medicine
# Anti Aging and Regenerative Medicine
# Surgery
# Internal Medicine
# Otolaryngology
# Pediatrics
# Ophthalmology
# Orthopedic surgery
# Orthopedic Surgeon
# Internal medicine
# General Surgery
# Radiology
# nan
# Anesthesiology
# Gastroenterology and Hepatology
# General Physician
# Obstetrics &Gynecology
# HPB Surgery
# PEDIATRICS
# Orthopedics
# Dermatology
# Orthodontics
# Family medicine
# docmark_coli@yahoo.com
# s
# a
# Pedia
# Neurosurgery
# Otolaryngology Head and Neck Surgery
# Software Developer
# Family and general dentistry
# Otolaryngology-Head & Neck Surgery
# Ob gyn
# Obstetrics and Gynecology
# Internal Medicine - Endocrinology
# general pediatrics
# internal medicine
# Family dentistry
# Pediatrician
# Urology, Endoscopic Urology, Laparoscopic and Minimally Invasive Urology
# Pediatric Dentistry
# orthodontist
# Endocrinology
# Orthodontist
# Neurosurgery
# Entrepreneurship
# ENT
# General Practitioner
# General dentistry
# Pediatrics0112344
# Traditional Chinese Medicine Acupuncture
# Orthopedic Surgery
# ENT (Otolaryngology)
# Ear Nose Throat - Head & Neck Surgery (ENT-HNS)  Rhinoplasty and Facial Plastic Surgery
# Adult Medicine
# orthodontics
# Dentistry
# general dentistry,orthodontics
# Obstetrics & Gynecology
# Anesthesiologist
# Obstetrician/Gynecologist
# Aesthetic Dermatologist and Cosmetic Surgery
# General Surgery, Neurosurgery
# Otorhinolaryngologist-Head & Neck Surgery/ENT
# Psychiatry
# Urology
# Orthopaedic Surgery
# General Surgery and Cancer Surgery/Breast Cancer Surgery, Laparoscopic Cholecystectomy, Thyroid Surgery
# internal Medicine
# Anesthesia
# Otorhinolaryngology - Head and Neck Surgery
# ENT-HNS
# pediatrics
# Orthodontist and  Oral Surgeon
# General and Cancer Surgeon
# OB Gyn
# Physical Medicine and Rehabilitation
# Cataract Surgeon and Comprehensive Ophthalmologist
# Child and Adult Psychiatry
# Alternative and Integrative Medicine
# General and Basic Laparoscopic Surgery
# Primary Care
# General Pediatrics
# Oral & Maxillofacial Surgery
# Cardiac Surgery
# pediatric
# Emergency Medicine
# internal Medicine, General Oncology
# general surgery
# PATHOLOGIST
# psychiatric
# Plastic Surgery, Reconstructive and Aesthetic Surgery, Burns Surgery
# Orthodontics,Endodontics
# surgery
# Optometrist
# Occupational Medicine / General Practice
# Obstetrics Gynecology
# Orthopaedic surgery
# Primary skin-health care
# general
# PEDIATRICS
# OB-GYNE
# Optometry
# Otolaryngology - Head & Neck Surgery
# General Medicine
# General, Cancer & Laparoscopic Surgery
# OB-GYN
# Med
# Neurology
# Ophthalmology - Diseases and Surgery of the Eye
# Pulmonary Medicine
# Family medicines
# General Practice
# General surgery
# Ent
# Internal Medicine
# General, Cancer & Laparoscopic-Robotic Surgery
# Primary  Care
# OB-GyN
# INTERNAL MEDICINE
# therapy
# internal blah
# Cellular Nutrition
# General medicine
# Family Medicine, Health Science
# General Adult Psychiatry
# General Dentistry/Orthodontics
# Adult Neurology
# obstetrics and gynecology
# OB-Gyn
# Orthopaedic Surgeon
# Medical Oncology
# Clinician
# Pediatric
# jj
# Cosmetic surgery
# pediatrics. family medicine
# surgery
# Child and Adult Diseases
# IM
# OBSTETRICS AND GYNECOLOGY
# Orthopedic Surgery + Traumatology
# General Opthalmology
# Orthodontics
# Occupational Medicine
# Family Medicine and School Health
# General Cancer and Laparoscopic Surgery
# Ear, Nose, Throat - Head & Neck Surgery
# Opthalmology
# GP
# Orthopaedics
# Obstetrician - Gynecologist
# Allergy
# Family Medicine/ Ambulatory Diabetes Care
# TMJ Specialist , Orthodontist
# Otorhinolaryngology - Head & Neck Surgery
# Othodontics
# Pain Medicine
# General Dentistry, Orthodontics, Implants
# Internal Medicine, Concierge Medicine
# General and Cancer Sirgery
# general practitioner
# orthopaedic surgery
# OB-GYNE, publoic Health
# General Medicine-EMS
# General Orthopaedics and Trauma Surgery, Arthroscopic Shoulder Surgery and Arthroplasty
# General
# Inte
# Physical Medicine & Rehabilitation
# GENERAL SURGERY
# Obstetrician gynecology
# OBSTETRICS & GYNECOLOGY
# Interventional radiology
# Radiation Oncologist
# Child and Adult Medicine
# Dermatologist | Dermatology | Adult & Pediatric Conditions of the Skin
# family medicine
# Adult Cardiology
# Dentistry
# Physical Rehabilitation
# Occupational medicine
# DMD
# Aesthetic, Occupational Medicine
# wqeqwe
# dentistry
# orthopedics
# Radiation Oncology
# Ob-gyne
# Hematology - Internal Medicine
# esthetic
# Pediatrics
# General Pediatrics and Adolescent Medicine
# Otolaryngology, Head and Neck Surgery
# Oftalmo
# Medical Informatics
# Dental Medicine
# Aesthetic Medicine
# ob-Gyne
# Obstetrics
# obstetrics gynecology
# Fellow Philippine Academy of Family Physician
# Critical Care
# Cardiology
# Plastic Surgery
# Urologic Surgery
# Geriatrics
# Pediatric Medicine
# ENT-Head and Neck Surgery
# General practitioner
# Orthopaedic surgeon
# Internal Medicine of Pokemons
# Exterior Medicine
# Child Neurology and Epilepsy Specialist
# Ophthalmologist with Otorynlogist
# Cardiovascular and Thoracic Surgery
# General Surgery and Surgical Oncology
# Internal Medicine-Adult Cardiology- Heart Failure
# Medical acupuncture
# General Orthopedids
# General pediatrics
# Obstetrician-Gynecologist
# General practice
# Internal  Medicine
# Internal Medicine- Hematology
# Obsteitrics and Gynecology
# Internal Medicine, Nephrology, Kidney Diseases, Dialysis, And Transplantation
# Pain and Anesthesia
# Genitourinary and Reproductive Medicine
# ophthalmology/ otorhinolaryngology
# Dermatology
# Geral
# Family Medcine
# Tropical Medicine
# Nephrology
# Obstetrics and gynecology
# General Laparoscopic & Cancer Surgery
# Adult Rheumatology
# General Internal Medicine
# Adult and Children's Diseases/Functional/Integrative/Complementary Medicine
# main specialty
# Physical Therapy | Strength and Conditioning
# General, Cancer and Laparoscopic Surgery
# Obstetrics Gynecology
# Physical Therapy
# Surgery,Family Medicine
# Gynecologic Oncology
# Interventional Cardiology
# Ear, Nose & Throat - Head and Neck Surgery
# DERMATOLOGY
# General Practitioner
# Orthopaedics Surgery
# occupational medicine
# Cardiac surgery
# Ophthalmology
# Adult Neurology and Psychiatry
# General practitione
# Legal Medicine And Forensic Medicine
# Dermatologist
# Rehabilitation Medicine
# Family Medicine
# Otorhinolaryngology - Head and Neck Surgery
# Otolaryngolgy
# Legal Medicine
# Public Health
# Medical Aesthetics
# OB-GYN, Family Medicine, Integrative Medicine
# Surgery
# Developmental & Behavioral Pediatrics
# Test
# cardiology
# Surgical Oncology, General Surgery
# Refraction
# Internal Medicine-Endocrinology
# General dentistry & Orthodontics
# Internal Medicine
# OB-Gyne
# Genrela Dentistry Practicing Orthodontics And Esthetic Dentistry
# Pathology
# Cosmetic Dermatology
# Ophthalmology, Facial Cosmetic Surgeon
# Dental
# Internal Medicine - Infectious Diseases
# Prosthodontist
# Infectious Disease
# GENERAL  SURGERY
# Obstetrics-Gynecology
# Orthopaedic Spine Surgery
# CLINICAL CARDIAC ELECTROPHYSIOLOGY
# Obstetrics And Gynecology
# Orthodontics and implant dentistry
# Cosmetic Surgery
# OB GYN
# Rheumatologist
# Neurology
# Obstetrics/Gynecology
# Pediatric Cardiology/Pediatrics
# Programmer
# Pediatrics | Primary Care
# man
# Medical Oncology
# Things
# Internal Medicine- Endocrinology, Diabetes and Metabolism
# Internal Medicine - Gastroenterology
# orthopaedics
# Pediatric
# GASTROENTEROLOGY
# Family and Occupational Medicine
# Adult cardiology
# OB Gyne
# Sports Rehab
# general dentistry
# ENT - HNS
# General and Laparoscopic Surgery
# Family and Community Medicine
# Ob-Gyn
# General Surgeon
# OPHTHALMOLOGY
# abc
# Ophthalmologists
# General  Surgery
# Nuclear Medicine
# General and Cancer Surgery
# Pediatric Cardiology
# general medicine
# Obstetric and Gynecology
# Internal Medicine - Nephrology
# Gastroenterology
# PEDIATRICS / ANTI AGING
# REHABILITATION MEDICINE
# Urology, General Surgery
# ObGyne
# Nursing
# obgyn
# Ear Nose and Throat - Head and Neck Surgery
# UROLOGIST
# Physical and Rehabilitation Medicine
# Spine & Orthopaedic Surgery
# Ob gyne
# IM-Gastroenterolgy
# Ophthalmology - Eye Doctor
# Chinese Medicine
# Otorhinolaryngology- Head & Neck Surgery
# Internal Medicine, Pulmonology
# OB GYNE
# Ob-Gynecologist
# Child and Adult medical consults
# Obstetrics and Gynecologist
# Obstetrics-gynecology
# bbbb
# Obstetrician/ gynecologist
# abbb
# Pulmonology
# Medicine
# General physician
# Urologic surgeon
# Internal Medicine - Cardiology
# None
# Integrative Medicine and Lifestyle Medicine
# Family and community medicine
# ENT Head and Neck Surgeon
# super saiyan
# isiwiwiw
# extraction
# INTEGRATIVE MEDICINE
# Pulmonology
# OB
# dermetologist
# Db
# Family  medicine
# OBGYN
# General practicioner
# Main
# Ll
# Astronomer
# Paladin
# Pain Management
# Internal Med
# Obstetrician Gynecologist
# Aesthetic and Integrative Functional Medicine
# Family Medicine - Diabetology
# Cardio
# Im
# Internal Medicine - Pulmonology
# M
# Obstetrician and Gynecologist
# Cosmetic and Implant Dentistry
# Family Madicine
# Cardiologist
# cardio
# Developmental and Behavioral Pediatrics
# m
# ENT (Otolaryngology)  - Head & Neck Surgery
# Otorhinolaryngologist Head and Neck Surgeon
# Ob-gyn
# as
# TMJ - Ortho
# Adult Cardiology
# Occupational Health
# VA
# ER
# ggg
# hospital management
# SolSee
# aesthetic medicine
# dermatology
# Internal - Pulmonary Medicine
# NEUROSURGERY
# Diplomate and Fellow in Internal Medicine - Certified Hypertension Specialist / Diplomate and Fellow in Family Medicine - Palliative Care Specialist
# Obstertric & Gynecology
# Orthodontics, Cosmetic Dentistry
# Leading You To True Health
# Internal Medicine - Adult Nephrology
# ENT-Head and Neck Surgeon/ Rhinoplasty Surgeon
# internal med
# Obstetrics&Gynecology
# Peidatrics
# immunity
# aaaaaaaaaaa
# Internal Medicine-Endcorinology
# Fellow, Philippine Obstetrical & Gynecological Society
# Naturopathic Medicine
# im
# SURGUYYY
# Department of Internal Medicine
# General Dentistry, Orthodontics
# General dentistry, Orthodontics
# Internal Medicine-Cardiology
# Urologic Surgeon
# Obstetrics and Gynecology - Gynecologic Oncology
# general physician
# General Practicioner
# Neonatalogist
# MD
# Orthopaedics and Traumatology
# Ear, Nose, Throat, Head, Neck Surgery
# Family
# Primary care
# ophthalmology
# Lactation Support
# cardiac
# ef
# Internal Medicine - Lung Disease Specialist
# Family Doctor
# Child
# Obstetrics - Gynecology
# Electronic
# Internist
# genral dentistry
# Surgery (& More)
# Internal Medicine (IM/ Adult Medical Specialist)
# ya
# Esthetic/Cosmetic Dentistry, Implants & Orthodontics
# Obgyne
# 1
# Rehab
# MainS
# 1231
# MS
# 123
# Physical Rehabilitation & Medicine
# Internal Medicine - Endocrinology, Diabetes and Metabolism
# physical rehabilitation
# Physical therapy
# Physical medicine and rehabilitation
# Internal Medicine/ Cardiology
# General Surgery And Diving Medicine
# Doctor
# General Medicine, Occupational Medicine, and Public Health
# Otorhinolaryngologist
# Hospice and Palliative Medicine
# Orthodontics, Implant Theraphy
# Otorhinolaryngology-Head and Neck Surgery
# Neurology & Psychiatry
# Psychology
# Diplomate Philippine Pediatric Society
# Urology, Kidney Stones, Urologic Cancers and Prostate Specialist, Endourology and Laparoscopic Urology
# Endocrinology (test)
# Breast Surgical Oncology
# Otolaryngology- Head And Neck Surgery
# Gyenacology
# Neurology -Vascular(Stroke)
# Internal
# Emergency medicine
# ophtha
# Opthamology
# Human Resource Management
# Internal Medicine; Lifestyle Medicine
# pulmonary medicine
# Physician
# Aesthetic Dermatology
# Opta
# Otorhinolaryngology Head and Neck Surgery
# Gynecologist
# Otorhinolaryngology
# Internal Medicine - Adult Cardiology
# Infertility
# ObGyn
# Otolaryngology - Head and Neck Surgery
# Otorhinolaryngology, Head and Neck Surgery
# Emergency
# Microblading
# General, Laparoscopic and Cancer Surgery
# Fellow, Philippine College of Surgeons, Inc
# Commercial
# Sport Med
# Diplomate in Internal Medicine
# OB-GYn
# General Dentistry and Orthodontic
# Internal Medicine - Adult Diseases
# Integrative Medicine
# Internal Medicine, Occupational Medicine
# Aesthetics And Dermatology
# OB Gynecologist
# Family med
# Ophthalmologist
# Pediatric Nephrology
# obgyne
# Orthopedics & Sports
# Doctor Of Chiropractic
# Obstetrician Gynecologist
# xxx
# Pediatric Surgery
# Occupational Safety And Health Physician
# Dental Implantologist
# Med Student
# Family Practice
# Urology test
# ORTHOPEDIC SURGERY
# INTERNAL MEDICINE PULMONOLOGY
# General Medicine for Adults  Thyroid Diseases
# Testing
# IT for Doctors
# Medical Student
# asd
# Pediatrics Neonatology
# Oral Surgery
# General & Endocrine Surgery
# Thoracic And Cardiovascular Surgery
# Neurology-Psychiatry
# NerveTherapy
# Otolaryngologist
# Internal Medicne
# Internal Medicine-Pulmonology
# Medical Officer
# logistics
# Orofacial pain and TMD
# Derma
# test
# Oto Rhino
# Rehabilitation Sciences
# Neurology - Pain Management
# system analysis
# Muscluloskeletal Rehab
# INTEGRATIVE MEDICINE & NATUROPATHY / FAMILY MEDICINE
# Aesthetic
# pediatric, er nurse, woundcare nurse
# Intern
# Functional and Integrative Medicine
# Nutrition
# OB-GYN/ General Practice in Female Reproductive Health
# Small Animal Medicine
# Surgery: General Surgery
# Oncology
# Diagnostics
# Dental Implant,Oral Maxillofacial Surgery, Orthodontics and TMJD
# Chiropractic
# Dermatologists
# General Practioner
# Rural Health Physician
# Internal medicine, Cardiology
# Ob Gyn
# Obstetrics and Gynecology - Reproductive Medicine and Surgery
# Ms
# Adult Pulmonologist
# family medicene
# Plastic, Reconstructive and Aesthetic Surgery
# NORMAL DELIVERY and WELL BABY
# Pediatrics and Clinical Genetics
# HIV Counseling and Care
# DIABETES EDUCATION
# Urologist
# Obgyn
# Internal Mediciine
# Interventional Cardiology/ Adult Cardiology/ Internal Medicine
# MCH
# MDS
# Internal Medicine  Emergency Medicine
# Aesthetics
# Kidney Transplant and Vascular Surgery
# PT
# General surgeon
# Anaesthesiology
# Internal Medicine- Adult Cardiology
# Diagnostic & Therapeutic Nuclear Medicine
# RADIOLOGY AND IMAGING
# General Surgery and Cancer Surgery
# GENERAL PRACTICE
# Cataract & Refractive Surgery
# Nutrition & Fitness
# orthopedic
# chiro
# SPORTS INJURY
# Osteopath
# Physics
# Oral And Maxillofacial Surgery
# Orthopedics - Oncology & Spine Surgery
# Vision Problem
# Heart
# Pediatrics - Pulmonology
# MEDICINE
# Orthopaedic
# General And Laparoscopic Surgery
# specializzando in igiene e medicina preventiva
# Post grad intern
# Internal Medicine - Endocrinology, Diabetes And Metabolism
# Cosmetic Dermatologist
# OBGYN - Infectious Diseases
# Applied Behavior Analysis
# General Dentistry, Orthodontics, Surgery
# dentist
# Internal Medicine - ENDOCRINOLOGY, Diabetes, Metabolism, Osteoporosis, Thyroid, Pituitary, Adrenal & Other Hormonal Disorders
# General Surgery, Laparoscopic Surgery
# General optometry
# GENERAL PRACTITIONER
# Addiction Medicine, Rehabilitation, Addiction Counseling
# General Dentistry, Endodontics
# Nephrologist
# Neurology | Internal Medicine
# OBSTETRICIAN-GYNECOLOGISTS
# Ayurveda Paediatrician
# In
# Addicion Medicine
# Chriopractic
# General Surgery; Urology
# Obstetrics and gynaecology
# Internal Medicine - Rheumatology
# Occupation Medicine
# Family Medicine, Palliatve Medicine
# primary care
# Paediatrics
# Ortho
# Medico-Legal Practice
# Optha
# Cardiologist and Consulting Physician
# Optah
# ENT HEAD AND NECK SURGERY, Voice Surgery
# General Dentist
# Internal Medicine Resident
# OPTH
# main
# Pre Hospital Care
# Dentist
# F?s????e?ape?t??
# 3D
# PEDIA
# School Nurse
# Internal Medicine - Adult Cardiology - Echocardiography
# urolo
# Vascular Surgery
# AESTHETIC MEDICINES AND SEXUAL PROBLEMS
# Obstetrics And Gynaecology
# Orthopaedic Surgery and Trauma, Hip And Knee Surgery
# General and Cancer Surgery (Thyroid, Breast, Gallbladder, Hernia, Appendix, Colon, Hemorrhoids)
# Internal Medicine-Pulmonary Medicine
# IM-Nephrology
# General medichine
# Periodontics and Implant dentistry
# Ear Nose Throat - Head and Neck Surgery
# surgeon
# Anesthesiology and Family Medicine Resident
# Internal Medicine - Adult Neurology
# event coordinator
# none
# MainSpecialty
# Laparoscopic Surgery
# Dog and Cat Medicine
# Internam Medicine
# IMTERNAL MEDICINE
# Internal Medicine - Pulmonary
# general desntistry
# Diagnostic Radiology
# Adult Cardiology - Interventional Cardiology
# Small Animal Practice
# Skin Health Specialist
# Pediatric Pulmonology
# Cosmetics
# Primary health Care
# PHY
# IM - Rheumatology
# Internal Medicine- Rheumatology
# kirurgji
# Adult Cardiology, Electrophysiology and Pacing
# Companion Animal Medicine & Surgery
# zxczcxcxzcxz
# Internal Medicine Adult Cardiology
# Facial
# Diagnostic
# ABCD
# ET&T
# Internal Medicine/Adult Disease Specialist
# Vascular and Endovascular Surgery
# Infectious disease
# Orthopeadics
# Clinical and Aesthetic Dermatology
# OB/GYN
# Obstetrics and Gynecogy
# Rrr
# Neurology Psychiatry
# geberal , Orhtho, Implant
# Ophtha
# Gynea
# Implant Dentistry
# IDK
# Aesthetic medicine
# ob-gyn
# IM- Cardiology
# ob gyn
# physical medicine and rehabilitation
# Bio-energetic Screening
# Developmental-Behavior Pediatrics
# CARDIOTHORACIC SURGERY
# Endocrinology, Diabetes and Metabolism
# General & Cancer Surgery
# Pulmonary
# Hepatology
# Optometrist, Contologist
# a/a
# General Family Clinic
# clinical psychologist
# ad
# dental
# Internal Medicine - Gastroenterology - Obesity Medicine
# Pharmaceutical
# Internal Medicine - Hematology
# Colorectal
# IT
# Orthodontics, Pediatric Dentistry
# Conference
# DENTIST
# Emergency and General Medicine
# Secretary
# Internal Medicine, Medical Oncology
# Muscular Hypertropgy and Conditioning
# occupational medicne
# Surgical
# Pediatrics, Medicolegal
# Rehabilitation medicine
# Orthopaedics & Traumatology
# Pediatric Neurology
# sugery
# GENERAL PEDIATRICS
# Ear Nose And Throat-Head And Neck Surgery
# Ob-Gyne
# Obstetrics and Gynaecology
# Orthopaedics Surgery and Traumatology
# PLASTIC SURGERY
# MIS, General and Cancer Surgery
# ob gyne
# Diabetes - Internal Medicine
# OBGYNE
# Community Health Nursing
# Sleep Medicine
# Psyciatry
# Orthopedic Spine and Scoliosis Surgery
# Otorhinolaryngology Head And Neck Surgery
# Internal Medicine/ Diabetes/ Thyroid/ Metabolism/ Endocrine Diseases
# INTERNAL MEDICINE/PULMONOLOGY
# Ear, Nose, Throat Head & Neck Surgery
# PMR
# Spine Diseases and Surgery
# cabs
# SPECIALTY
# International Medicine
# MHA
# Oral and Maxillofacial Surgery
# aoeu
# Mycological
# Internal Medicine Gastroenterology  and Nutritional Diseases
# ooooo
# Internal Medicine-Diabetology
# General practitioners
# Medicine General
# UROLOGY
# InstaSmile Dental Clinic
# General Practian
# Fellow - Philippine Dermatological Society
# Renal
# pediatrician
# '><img src=x onerror=prompt(1)>
# b
# GeneralSurgery
# OBGyne
# Hematology/Internal Medicine
# Functional Medicine
# General Medicine - Occupation Health
# Ob Gyne
# Orthopaedic Surgery & Traumatology
# L
# Internal MEdicine
# General Peds
# Neurology And Psychiatry
# Internal Medicine-Hematology
# Endocrinologist
# RN/A
# Obstetrician
# Familu
# Adult and Pediatric Asthma, Allergy and Immunology Specialist
# Hematology
# diabetologue
# GENERAL DENTISTRY
# General Medicine Family Medicine
# Rehabilation Medicine,
# Family Med
# PGI
# 123123
# OBSTETRICIAN GYNECOLOGIST
# gaga
# Pediatrics-Infectious Disease
# Natural Medicine
# Retired
# md
# AAAAAAAAAAA
# A
# AAA
# Omomi
# Ent Head And Neck Surgery
# Osteo
# Truma
# legs
# Nuero
# afsf
# SCRIBE
# Family Dentistry
# Information Technology
# General and Laparoscopic Surgery   |   Gallbladder, liver, pancreas, gastrointestinal, thyroid, breast, tumor, appendix, hernia, hemorrhoids, fistula, circumcision, chemocath insertion, ultrasound
# General Dr
# medcine
# Oral Implantology & Surgery,Orthodontics,Endodontics,Prosthodontics
# Internal Medicine- Adult Cardiology/ Vascular Specialist
# IT SPECIALIST
# pedia
# Loves Kids
# Bed Making
# family med
# Internal Medicine & Cardiology
# Medical Services
# Quality Services
# EENT
# Rehabilitation Therapiat
# BS
# Hjj
# Cardiologue
# Kids Care
# Iridologist
# Midwife
# Clinic
# ONLINE KONSULTA
# CARDIO
# INTERNAL MEDICINE-Geriatrics
# IM-PULMONARY MEDICINE
# Thoracic Cardiovascular Surgery
# INTERNIST-PULMONOLOGIST
# SURGERY
# Internal Medicine - cardiology
# Cardiology / Internal Medicine
# Administration
# Com
# Emergency Medicine, Pediatrics
# Small Animal Medicine and Surgery
# Internal Medicine - Pulmonary Medicine
# Interventional cardiologist
# AS
# nope
# DVM
# B
# Minimally Invasive and Laparoscopic Surgery
# Internal Medicine/pulmonary
# Occupational Therapy
# Veterinary Medicine
# Internal Medicine Pulmonology
# Inetrnal medicine
# adasd
# Geriatric Medicine
# Sports
# Swine Medicine
# degree
# Aaa
# Yy
# Family Dentist
# Physiatry
# Internal Medicine, Diabetes, Thyroid, Hormone Disorders
# General Physician
# oral
# lkjsadlfkj
# kdsjflkfdsjg
# internal
# Internal Medicine-
# Obsterics and Gynecology
# Asistant
# Physiotherapy
# Internal Medicine-Pulmonary and Critical Care Medicine
# Lifestyle Medicine
# Thoracic and Cardiovascular Surgery
# cfvhgbjnk
# Med sec
# Yg
# Internal surgery
# Internal Medicine, Family Medicine
# Acupuncture
# Liver, kidney and pancreas transplant
# ENT Head and Neck Surgery
# Surgical Oncology, Breast Surgery
# medicine
# radiology
# veterinary
# General Medicine / Public Health
# Cardiologist.
# ADDICTION MEDICINE
# Anesthesiologu
# Internal Surgery
# Sugeon
# dental medicine
# ortho
# E-Med, Nephrology
# Rheumatology and Autoimmune Diseases
# Me :)
# Breeding Uroplatus
# Absenos
# qweqwe
# zzz
# nnnnnn
# ob-gyne
# Obstetrician- Gynecologist
# NURSING
# Otorhinolaryngology - Head and Neck Surgery /ENT / Diseases of the Ears, Nose, Throat
# Electronic s
# surgry
# Psychiatric
# School check up
# sdf
# Dentistry, Orthodontics
# Veterinary
# Internal Medicine - Diabetes, Thyroid and Endocrinology
# Optical
# Software
# General Physician/ Occupational Health physician
# Radiologist
# Internal Medicine/ Adult Medicine
# Otorhinolaryngology (ENT)
# General Medicine | Occupational Medicine
# FAMILY MEDICINE
# pathology
# Occupational and General Medicine
# Genera
# Audiology
# Addiction
# psychiatrist
# non
# Special
# Ob
# Genera Pediatrics
# Emergency room
# Aesthetics and Anti-Aging
# obsetitric gynacology
# ob_gyn
# OBGYN, OCCUPATIONAL HEALTH AND SAFETY PHYSICIAN
# ob
# Internal Medicine-Gastroenterology and Digestive Endoscopy
# GENERAL MEDICINE
# Oriental Medicine
# Otolaryngology head and neck surgery
# n
# Plastic Reconstructive and Aesthetic Surgery
# 12
# Aesthetic Medicine, Occupational Health and Safety Physician
# ORTHODONTICS
# Reproductive Endocrinology and Infertility ; Gynecologic Endoscopy
# Internal Medicine / Kidney Diseases / Hypertension
# Cardiothoracic and Vascular Surgery
# Sexual Health
# Internal Medicine -  Endocrinology, Diabetes, Thyroid, Hormone Disorders and Metabolism
# Internal medicine,kidney stone specialist
# Internal Medicine - Adult Medicine
# INTERN
# FAMED
# Urogynecology, Advanced Gynecologic Laparoscopy, Obstetrics and Gynecology
# Maternal & Child
# Developmental and Behavioral Pediatrician
# General practioner
# General Surgery / Thoracic & Vascular Surgery
# Family Medicine/ObGyn
# OB-gyne
# Gen Medicine
# FAMILY PRACTICE
# AGREE
# Primary Care Practitioner
# WOMEN HEALTH
# Wound Specialist
# Hospital Pharmacy
# medical secretary
# Aesthetic and Anti-aging Medicine
# Cardiothoracic surgery
# Your Health Is Our Priority
# Internal Medicine / Pulmonary & Critical Care
# Community
# General Practice, Primary Care
# Internal Medicine-Pulmonary
# PEDIATRIC
# Adult Infectious Disease
# Primary Health Care for Women and Children
# Patient care
# Internal Medicine - Pulmonary Medicine - Crical Care Medicine
# Manual Therapy
# Obstetrics And Gynecolog
# TEACHING
# Cardiac Rehab
# -
# Social Work
# Internal Medicine/ Pulmonary
# secretary
# Functional
# Anatomic and Clinical Pathologist
# Rheumatology
# Occupational
# Speech and Language Pathology
# Birthing Clinic
# ORTHOPEDICS
# Student
# Physical Tharapy
# Orthopedic Surgery and Traumatology
# Ob Gynaecologist
# Regenerative Medicine
# General and Laparoscopic Surgeon                    Occupational Medicine Specialist
# Associate In Computer
# Dhjdu
# Acupuncturist
# Me
# Adult Nephrology
# Md
# neurology
# Major in Genetics
# Obstetrician-gynecologist
# Internal Medecine
# MEDICINA GENERAL
# Ears, Nose, Throat Diseases-Head & Neck Surgery
# Internal Medicine, Gastroenterology
# Cardio Vascular
# General Dentistrry
# Chiropractor
# Holistic
# Med Tech
# General Thoracic Surgery
# Help
# OBGYN / Obstetrics and Gynecology / Womens ultrasound
# Medical Technology
# Internal Meds
# Pediatrics, Occupational Therapy, Speech Therapy, Physical Therapy, SPED
# Thoracic and Cardiovascular Surgery, General Surgery
# Pharmacy
# Internal medicine, Pediatrician, OB
# General Orthopedic Surgery
# MEDINICE
# Aesthetic and Dermatology
# P
# Pulmonologist
# G.P.
# In-Home Senior Health
# Rehabilitation Medicne
# veterinary medicine
# IM-Cardiology
# Internal Medicine- Medical Oncology
# Intern Medicine
# Venereologist
# Veterenary Medicine
# oral Surgery
# Internap Medicine
# 43
# Internal Medicine - Neurology
# Peadiatric
# Transplant Surgery
# Management
# INTERNAL MEDICINE - ADULT INVASIVE CARDIOLOGY - PERIPHERAL VASCULAR INTERVENTION
# Venipuncture
# Internal Medicine - Diabetology
# fdgf
# ertryty
# Medical
# Comprehensive Ophthalmology
# Internal MEDICINE
# General Med
# Internal Medicine & Diabetology
# Community Medicine
# Aesthetic, Dermatology
# Spine Surgeon
# BDS
# sdaf
# Computer
# sdfsda
# Infectious Disease and Tropical Medicine
# Orthoodntics
# Otolaryngology (ENT)
# Pediatrics - Hematology & Oncology
# Multi Specialty
# Ears Nose Throat  -  Head & Neck Surgery
# Brain
# Infectious Diseases
# Chiropracter
# Internal Medicine - Nephrology (Kidney Specialist)
# Internal Medicine / General Medicine
# Obstetric
# Advanced Minimally Invasive and General Surgery
# mental illness
# EAR NOSE THROAT - HEAD AND NECK SURGERY
# Narcology
# Surgeon
# Hepatobiliary and Pancreas Surgery, Advanced Cancer Surgery, Laparoscopic and Robotic Surgery
# Rehabilitation
# Intensive Care
# Interventional Radiology / Interventional Neuroradiology
# Cosmetic , Implants
# Urgent Care
# Neurologist
# Surgey
# na
# Geriatric Nursing
# Internal Medicine/Endocrinology
# Est qui minim et au
# Pediatric Dermatology
# Cosmetic Dentistry And TmjA Disorder
# Hull Engineering
# General Surgey
# Medical Surgical
# Family Medicine / Neurotoxicology
# Theraphy
# OB-GYN/ Integrative Medicine
# Health And Beauty
# General Dentistry, Aesthetic Dentistry
# Internal medicine,
# Hospital Management
# Pulmonary & Physical Medicine
# Psychiatry and Behavioral Medicine
# Information System
# CONSULTANT GENERAL SURGEON
# Psychistry
# Allergy, Asthma, General & Reproductive Immunology
# Ghhhhj
# Internal Medicine, Surgery,family Medicine
# DMD
# student
# OCULAR HEALTH
# Adult Neurologist, Neurocritical Care and Trauma Specialist
# Neurology - Internal Medicine
# GenDentistry
# Internal Medicine & Nephrology
# Adult Interventional Cardiology
# Mustache removal
# Obstetrics & Gynaecology
# MD, MPH
# Medical and Aesthetic Dermatology
# Orthopedic Spine surgery
# Internal Medicine-Adult Cardiology
# Computer Science And Technology
# Vascular surgery
# Osteopathy
# Derma Clinic
# Child Neurology
# Gsu
# Aesthetic and Anti-aging specialist
# AESTHETIC DERMATOLOGY
# fhhhf
# Aesthetic and Anti aging
# Emotional
# Internal Medicine & Adult Diseases
# Orthopedic Surgery :
# Oby
# DNA
# Canine and Feline Internal Medicine and Surgery
# Ophthalmology/Optometrist
# IM - Pulmonary and Sleep Medicine
# Medicine and Surgery
# gastrology
# Ttt
# Adutl Infectious Diseases
# Diagnostic Laboratory
# Ob Gune
# Obstetricsgynecology
# Comprehensive Ophthalmology
# nursing
# General Psychiatry
# Oral Surgery&Implantology, Craniodontics TMJ-Airway, Periodontics
# INTERNAL
# Pediatrics and Lactation
# Otorhinolaryngology, Head And Neck Surgery
# Internal Medicine - Adult Pulmonology
# COVID
# INERNAL MED
# Nephro
# Tropical Medicine And Infectious Diseases
# Internal Medicine-Endocrinology, Diabetes and Metabolism
# Surgery - general, laparoscopic and cancer surgery
# Internal Medicine - Medical
# Oncology
# Family and Palliative Medicine
# Otorhinolaryngology - head and neck surgery
# Internal medicine-Cardiology
# Medical oncologist
# Obstetrics -Gynecology
# General Psychiatry
# Internal Medici e
# Ear Nose Throat Head and Neck Surgery
# Eent
# Child Neurology and Neurodevelopment
# Pain
# Otorhinolaryngology - Head And Neck Surgery
# Internal Medicine / Gastroenterology
# OBG
# Orthopedic  Surgery
# Family Physician
# Healthcare
# General & Special Needs Dentistry
# Eyes
# opthalmology
# Internal Medicine - Pulmonology
# ORL HNS
# Pediatrics Cardiology
# BDS, FICCDR
# Neurology and Psychiatry
# Otorhinolaryngology-Head & Neck Surgery
# Ophthalmology - Orbit & Oculoplastic Surgery
# Pediatricsweh
# Neurology- Psychiatry
# Urologic Surgery and Kidney Transplantation
# Hearing, balance, ears
# Lifestyle Medicine, Primary Care
# Specialist Physiotherapist
# PSYCHIATRY
# Ship handling
# Otolaryngology- Head and Neck Surgery
# Ophthalmology - Cataract, Laser & Microsurgery of the Eye
# Sleep Specialist
# Internal Medicine- Gastroenterology
# GENERAL PHYSICIAN
# Ophthalmology-Otolaryngology
# Ear
# Internal Medicine/Adult Pulmonary Specialist
# PEDIATRIC NEUROLOGY
# TCVS
# Pulmonary Medicine, Internal Medicine
# IM Nephrology
# Internal Medicine- Endocrinology
# General Surgery, Adavanced Laparoscopic Surgery
# Internal Medicine - Adult and Interventional Cardiology, Adult Critical Care Medicine
# Child Health
# ENT Head & Neck Surgery
# IM-Pulmonary Medicine
# Hypatobillary
# General Surgery, Thoracic Surgery
# Hepatobiliary Surgery
# General Medicine - Occupational Medicine
# Dermatology - Diseases of the Skin, Hair, and Nails
# Ear, Nose, Throat & Head And Neck Surgery
# acctg
# mental health
# Internal Medicine -Adult Cardiology
# Obstetrics- Gynecology
# EARS, NOSE THROAT, HEAD AND NECK SURGERY
# Asthma & Allergy
# OB-GYNECOLOGY & UROGYNECOLOGY
# Family Medicine- Resident Physician
# Internal  Pulmonary Medicine
# IM-Nephrologist
# Lifestyle Medicine Specialist
# Orthopedic Surgery/ Trauma Surgery/ Spine Surgery
# Orthopedic & Spine Surgery
# Anethesiology
# Gh
# Anesthesia, General Practitioner
# Urology and Transplantation
# Internal Medicine-Diabetes
# ADULT NEUROLOGY
# General,  Cancer and Laparoscopic Surgery
# Otorhinolaryngology (Ear, Nose, Throat)- Head and Neck Surgery
# Plastic and Reconstructive Surgery
# nuero
# neurosurgery
# Family Medicin
# ANESTHESIOLOGY
# Adult Cardiology and Internal Medicine
# Otorhinolaryngology Head and Neck Surgery (ENT)
# EAR, NOSE, THROAT, HEAD and NECK SURGERY (ENT-HNS)
# Medtech
# PSYCHOTHERAPY
# Sleep Medicine/Sleep Studies (Polysomnographer)
# FM
# Obstetrician -Gynecologist
# Primary Care Physician
# I.T
# Sports Medicine
# General and Cancer Surgery | Laparoscopic Surgery
# PHYSICAL MEDICINE AND REHABILITATION
# Aesthetic Dentistry
# Internal Medicine / Diabetology / Goiter / Endocrinology
# Internal Medicine, Infectious Diseases
# Internal medicine, family medicine
# Adult Cardiologist
# Pain Medicine
# Radiology
# Radiation Oncology/ Oncology
# Endocrinology and Metabolism
# Specialty
# Internal Medicine-Gastroenterology
# Comprehensive Sex Education / Wellness Specialist
# Periodontology
# General Medicine & Skin Diseases
# Ear, Nose, Throat - Head and Neck Surgery
# OBGyn
# Otolaryngology Head & Neck Surgery
# Occupational Health; Family Medicine
# Otorhinolaryngology-Head and Neck Surgery (or ENT-HNS)
# Ears, Nose, Throat - Head and Neck Surgery
# Ear Nose Throat Head & Neck Surgery
# (ENT-HNS) Ear Nose Throat, Head and Neck Surgery
# ENT-HEAD AND NECK SURGERY
# TMJ Dentist
# ENT-Head and Neck Surgery/ Sleep Medicine
# ENT (Ears, Nose and Throat)
# internal medicine, diabetes
# Thoracic and Vascular Surgery
# Ear,Nose and Throat - Head and Neck Surgery
# Internal Medicine - Neurology
# INTERNAL MEDICINE-CARDIOLOGY
# Anti-Aging and Regenerative Medicine
# Ear, Nose. Throat- Head and Neck Surgery
# Specialty 1
# General and laparoscopy Surgery
# Cardiology - Internal Medicine
# Adult Medical Specialist
# cosmetics
# Emergency Medicine, General Medicine and Surgery
# Adult & Pediatric Allergy, Asthma, and Immunology
# Internist and Endocrinologist
# Skin Health and Aesthetic Dermatology
# Otorhinolaryngology - Head and Neck Surgeon
# OTORHINOLARYNGOLOGY
# IM-Gastroenterology
# Occupational Medicine ( Division of Phil. Academy of Family Physicians)
# Comprehensive Dentistry
# IM-GASTROENTEROLOGY
# Ok
# Otorhinolaryngology - Head and Neck Surgery (ENT - HNS)
# Endocronologist
# Pediatric dentistry
# Colon and Rectal Surgery
# Pediatrics and General Medicine
# General and Adult Psychiatry
# Physical Med& Rehab
# ENT (Otolaryngology) - Head & Neck Surgery
# Ears, Nose, Throat -Head and Neck Surgery
# DERMATOLOGY - Fellow, Philippine Dermatological Society, Inc.
# Internal Medicine/Cardiology
# Internal Medine
# Pulmonary Medicine
# Psychiatry & Behavioural Medicine
# IM - ONCOLOGY
# Internal Medicine, Diabetes, Thyroid and Endocrinology
# Primary & Aesthetic Skin Health/ Occupational Medicine/Primary Care
# Human Resources
# Veterinary medicine
# Internal Medicine/Allergy
# Orthopedic Trauma
# ENT-HNS Sleep Medicine-Sleep Surgery
# Adult & Pediatric Allergology - Immunology / General Pediatrics
# Nutrition and Diet Therapy
# Web Development
# Dermatology - skin, hair and nails
# General Psychiatry and Behavioral Medicine  (Adult)
# Adult Pulmonary Medicine & Internal Medicine
# obstetric-Gynecologist
# Obsterics And Gynecology
# OBSTETRICIAN-GYNECOLOGIST
# Diplomate In Internal Medicine
# General Urology
# Ear Nose Throat-Head & Neck Surgery
# Intetnal Med.- Diabetology
# IM-MEDICAL ONCOLOGY
# Consultation
# GYNECOLOGIC ONCOLOGY
# Ear Nose Throat Specialist - Head and Neck Surgery
# Ophthlamology
# ENT HNS
# ENT - Head and Neck Surgery
# INTERNAL MEDICINE-GASTROENTEROLOGY
# Internal Medicine/ Adult Cardiology
# Pediatrics - Pulmonology
# Orthopaedics Spine
# PEDIATRICIAN
# INTERNAL MEDICINE-MEDICAL ONCOLOGY
# Endocrinology, Diabetes and Metabolism
# Adult Endocrinology
# Allergists/Immunologists
# Internal Medicine-Nephrology
# General Ophthalmology
# Adult and Pediatric Neurology
# ABC
# GP/Ortho
# Integrative Medicine, General Medicine, Acupuncture
# Internal Medicine - Endocrinology, Diabetes, and Metabolism
# OTORHINOLARYNGOLOGY HEAD AND NECK SURGERY
# Emergency Medicines
# Lifestyle and Anti-aging Medicine
# Ear, Nose, Throat/ Otorhinolaryngology-Head and Neck Surgery
# Otolaryngology - Head and Neck Surgery (ENT-HNS)
# Internal Medicine-Gastroenterologist
# Adult and Pediatric Allergy and Immunology
# General Laparoscopic and Cancer Surgery
# ertertertert ertert
# Allergy / Immunology
# Internal Medicine, Adult Cardiology
# Aesthetic Facial Surgery, Cosmetic Surgery, Ophthalmology, Plastic Surgery,
# Eye, Ear, Nose and Throat
# Functional Medicine and Lifestyle Medicine
# General Medicine & Aesthetic Medicine Practitioner
# General & Minimally Invasive Surgery
# Patient
# Paediatric
# Dermatology (Adult and Pediatric)
# Ear Nose & Throat - Head and Neck Surgery
# Physical Therapist
# Integrative and Holistic Medicine / Functional Medicine / Traditional Chinese Medicine (Acupuncture)
# Nothing
# Diplomate, Internal Medicine
# OBSTETRICS-GYNECOLOGY
#  Obesity Medicine and Lifestyle Medicine
# Dermatology (Medical & Cosmetic)
# ENT Surgeon
# MEDICAL ONCOLOGY
# Gen Surgery
# Pediatrics-Pulmonology
# Physical Rehabilitation Medicines
# Internal Medicine Gastroenterology
# OB-GYN, Family Medicine
# Ear, Nose, Throat, Head and Neck Surgery
# Internal Medicine - Allergy & Immunology
# Acu
# Otorhinolaryngology-Head And Neck Surgery
# Genitourinary and Stone Diseases
# Obstetrics- Gynaecology
# Pediatric Hematology-Oncology
# on-gyn
# Allergists
# Allergology and Immunology, General Pediatrics
# Adult Hematology
# Ears Nose Throat Head and Neck Surgery
# Otolaryngology-Head and Neck Surgery
# orthopedic surgery
# Ears, Nose , Throat , Head and Neck Surgery
# Ear, Nose, Throat/Otorhinolaryngology-Head and Neck Surgery
# Ears, Nose, Throat - Head & Neck Surgery
# Ent head and neck surgery
# Gynecologic oncology
# Adult And Interventional Cardiology
# Psych
# Pediatrics and Child Health
# Occupational Medicine / General Practitioner
# Ear, Nose, Throat,  Head and Neck Surgery
# Gastroenterologist
# Uro
# uro
# Otorhinolarygology Head and Neck Surgery
# Doctor of Pharmacy
# Interna Medicine
# Internal Medicine Gastroenterology
# General Medicine, Dermatology
#  Integrative Medicine
# OBSTERICS AND GYNECOLOGY
# Internal Medicine- Cardiology St. Luke s Medical Center BGC
# ENT- Head And Neck Surgery (Otolaryngology)
# TMJ-Orthodontics
# Pediatrics, General Surgery
# Internal Medicine / Primary Care
# Kidney
# Doctor Payton
# Radtech
# Gastro
# Degree
# Nuclear Medicine and Thyroid Diseases
# Ophthalmology/Glaucoma/Cataract and Comprehensive Ophthalmology
# Internal Medicine Adult Diseases Specialist
# Ob, Geria
# Transplant and Vascular Surgery
# Diplomate In Geriatric Medicine
# OBTETRICS AND GYNECOLOGY
# Ob-gyn and Sonologist
# Urology/Genitourinary Surgery
# Otolarygology
# OBSTETRICS and GYNECOLOGY
# Ophtalmology
# General Practicioner - Primary Care Physician
# Orthopedics and Spine Surgery
# Gastro Enterologist
# Pediatric and Adolescent Medicine
# Ob Gynecologist
# obstetrics and gynaecology
# General And Cancer Surgery
# neuro
# Internal Medicine - Cardiology and Vascular Medicine
# General Medicine, School Health and Lactation
# Otorhinolaryngology-Head and Neck Surgery(ENT-HNS)
# Adult Pulmonology and Critical Care Medicine
# Ob gyn/ GP
# Psychiatrist
# Hospital Nicu and womens health
# Neurological Surgery
# Nevrology
# Pediatrics Nephrology
# Internal med
# General Pediatrics / Pediatric Pulmonology
# Clinical Psychologist
# Surgery, Urology
# Otorhinolaryngology (ENT-HNS)
# Plastic And Reconstructive Surgery
# General and Minimally Invasive Surgery
# Ear Nose Throat Head and Neck surgeon (ENT-HNS )
# Physician Surgeon,Cosmetic Dermatology
# Municipal Health Officer - Bagac Bataan
# SPINE / ORTHOPEDICS TRAUMA
# UROLOGY, ADULT AND PEDIATRICS
# Otorhinolaryngology (ENT) - Head and Neck Surgery
# Dermatology ( Medical)
# Ear Nose Throat Head And Neck Surgery
# General, HPB, Laparoscopic Surgery
# So
# Ear nose throat-head and neck surgery
# Physical Medicine And Rehabilitation
# EAR, NOSE, THROAT AND NECK DISEASES
# Orthopedics, Hip and Knee Arthritis Specialist, Hip and Knee Replacement Surgery
# PLASTIC, RECONSTRUCTIVE AND AESTHETIC SURGERY
# Medical Dermatology
# General Medicine And Animal Bite Physician
# General Pediatrics
#
# Internal Medicine - Cardiology - Interventional Cardiology
# ENT/ Otorhinolaryngology-Head and Neck Surgery
# urology
# NeuroSurgery
# Orthopaedics and Spine Surgery
# Plastic surgery
# General Medicine, Occupational Medicine
# GS
# Otolaryngology Head and Neck Surgery (ENT-HNS)
# Orthopaedic and Hand Surgery
# Ophthalmology / Ophthalmologist / Eye Doctor / Eye Care Specialist / Comprehensive Ophthalmology
# Orthopedics and Traumatology
#
# DIABETES care Specialist
# General Surgery, Thoracic And Cardiovascular Surgery
# Anesthesiology and Pain Medicine
# Pediatric Gastroenterology
# Internal Medicine / Cardiology
# Manager
# Ear, Nose, Throat, Head & Neck Surgery
# Gastroenteroloy
# Biology
# Family Medicine Specialist
# general  and cancer surgery
# General Physican
# Injectables
# Otorhinolaryngology-Head and Neck Surgery (Diseases of the Ear, Nose and Throat)
# Internal Medicine - Adult Nephrology (Kidney Diseases)
# Ear Nose Throat
# Fellow in Family  & Community Medicine
# Dental Practice Management and Leadership
# General and Oncologic Surgery
# General Practiotioner
# Na
# General Medicine / Ophthalmology
# RALPh Roque
# Otorhinolaryngology- Head and Neck Surgery
# Infectious diseases
# Immunology
# Ear,Nose,Throat -Head & Neck Surgery
# patient
# Obstetrics/ Gynecology
# Climacteric Medicine
# Menopause
# Endo
# Surgery/ Occupational Medicine
# Orthopaedic Spine Surgery
# Internal Medicine/Gastroenterology
# General Practitioner, Public Health
# Obstetrician gynecologist
# Medical Secretary, Ophthalmology
# E.G
# Occupational Health Physician
# Lying-in Clinic
# Obstetrics and Pediatrics
# Pediatric Allergy
# Pulmonary & Internal Medicine
# Aesthetic Medicine & Anti-Aging
# Ears, Nose, Throat, Head and Neck Surgery
# General Pediatrics - Ambulatory
# Dermatology (adult and pediatric)
# Obstetrics, Gynecology
# Internal Medicine, Kidney Diseases, Hypertension
# anesthesia
# Obstectics
# Dental Medicine, Oral Maxillofacial Surgery
# OBSTERICS GYNECOLOGY
# Aesthetics & Wellness Medicine
# Family Medicine, General Medicine, Primary Care, Occupational and Industrial Medicine, Animal Bite Specialist, TB Specialist, Adult and Pediatric Infectious Diseases
# Surgical Oncology
# Gastroenterology & Hepatology
# Hemathology
# EAR, NOSE, THROAT-HEAD & NECK, THYROID SURGERY
# GP/ Pediatrics
# Obstetrics gynecology
# Obstetrics and Gynecology (OBGYN)
# PSYCHOLOGY
# Test account
# cardiologist
# IM- PULMONOLOGY
# Ortho spine Surgeon
# Clinical & Cosmetic Dermatology / Occupational Safety & Health Medicine / Venereology
# Hematologist
# Consultant in Family Medicine @ Rivera Medical Center, Inc.; Chief of Clinics; Training Officer Family Medicine Residency Program; Master in Hospital Administration
# Fellow, Adult Cardiology
# Ear, Nose , Throat - Head and Neck Surgery
# OTOLARYNGOLOGY (ENT)
# Pediatric Hematology
# Pediatric Hematology and Oncology
# Pediatrics
# .
# Otorhinolaryngology - Head and Neck Surgery (ENT)
# Dermatology & Aesthetics
# psychatry
# INTERNAL MEDICINE - GASTROENTEROLOGY
# Internal Medicine/Adult Cardiology
# Web Developer
# F
# Cardiology, Internal Medicine
# General, Cancer, Laparoscopic, and Trauma Surgery
# Cecilia gonzales
# IM-Cardiologist
# DENTISTRY
# General Medicine-Occupational Health Physician
# Family Medicine (Diplomate)
# DEVELOPMENTAL AND BEHAVIORAL PEDIATRICS
# PEdiatrics
# PEDIATRIC CARDIOLOGY
# Ear, Nose and Throat-Head and Neck Surgery
# Gp
# Ear, Nose, Throat-Head and Neck Surgery
# Internal Medicine -Cardiology
# Adult Pulmonary Medicine
# CLINICAL PSYCHOLOGY
# Clinical Embryology and Assisted reproduction technology
# Ear, Nose Throat-Head and Neck Surgery
# Aesthetic  and Anti-Aging Medicine
# Pulmonologist
# Fellow PSO-HNS, ENT-HNS (Voice, Swallowing, Nose, Nasal Sinuses, Head and Neck Surgery)
# Neurology, Stroke Specialist
# Anatomic and Clinical Pathology
# Interventional Radiology, Vascular and Interventional Radiology
# General Practice/ Maritime Medicine
# Welder pipe filter
# RN
# Internal Medicine - Medical Oncology
# Dematology
# Mental Health
# Internal Medicine | Dermatology
# Reumathology
# Endocrinology, Diabetes Mellitus, Thyroid Diseases
# General Surgery, Trauma Surgery And Critical Care
# Breast Surgery
# Internal Medicine - Gastroenterology, Digestive Endoscopy
# otolaryngology
# GASTROENTEROLOGIST
# Patienr
# Adult Psychiatry
# family
# ORL-HNS
# Sorry wrong sign up
# INTERNAL MEDICINE - CLINICAL ENDOCRINOLOGY
# PLASTIC AND RECONSTRUCTIVE SURGERY
# Nutritional Family Practice
# general practice
# Otorhinolaryngology, Head & Neck Surgery
# follow up check up
# ENT Otolaryngology
# General Orthopedics
# Pediatric Gastroenterology, Hepatology and Nutrition
# Eyes,Ears,Nose,Throat
# Internal Medicine/Gastroenteology/Hepatology
# infertility
# Oral Sugery
# General Dermatology
# Plastic, Reconstructive and Aesthetic/Cosmetic Surgery
# Anesthesiologiy
# Cardiovascular
# ENT Otorhinolaryngology
# Fellow, Family Medicine
# Liver
# appointments
# Allergology
# Computer Science
# Medical Secretary
# Family medecine
# sdd
# oral and maxillofacial surgery
# General Physician (Pediatrics and Adult)
# Marc
# Orthopaedics (Bone and Joint Surgery)
# Generalists
# Public Health, Pathology
# Internal Medicibe
# Emergency Medicine, Primary Care
# OB/RM check up
# Helping mother to gave birth by normal delivery
# Internal Medicine, Cardiology, Interventional Cardiology
# Otorhinolaryngology-HNS
# Internal Medicine, Endpcrinology & Metabolism
# Newborn Medicine
# Dermatology (Skin, Hair, Nails)
# ENT, Head and Neck
# IM-Hematology
# Obstetrics Gynecology, Aesthetic Dermatology
# Internal medicine - Gastroenterology
# Hshshs
# Cancer
# Clinical & interventional pulmonology
# DERMATOLOGIST
# Hahaha
# Clinical Optometrist
# w
# Gastroenterology & Transplant Hepatology
# Clinical Nutrition
# Intensive care medicine
# Neuroscience
# Test Only
# General Surgery Pediatric Surgery
# Child & Adult Allergy, Asthma & Clinical Immunology
# Dermatolgoy
# Neuro
# ADULT CARDIOLOGY & INTERNAL MEDICINE: Heart Failure, Chest Pain, Hypertension (high blood pressure), Coronary Artery Disease, ECG, Hypertrophic Cardiomyopathies, Arrhythmias, & other heart diseases
# Babag
# Pre-Med
# Occupational Medicine / General Medicine
# Plastic Surgery (Reconstructive & Aesthetic / Cosmetic) / Burns
# OB-Gynecology - Ultrasound
# Public health
# computer science
# General Practice / Occupational Health
# Family Meeicine
# Internal Medicine - Adult Nephrology
# accounting
# Internal Medicine - Allergy and Immunology
# ENT (Otorhinolaryngology - Head and Neck Surgery) / General Medicine
# Handling Normal Deliveries
# Reproductive Endocrinology
# Pediatrics, Infectious Disease
# OB and gynaecology
# Test Specilty
# General Practioners
# Rhematolgy/Arthritis
# Dra. Beverly Dela cruz
# IM- Endocrinology
# M.D , DPPPS
# computer
# General Medicine, Primary Care
# Father
# Oral
# Oral Surgery, Prosthodontics, General Dentistry
# Midwifery
# Fellow of the Philippine Academy of Family Physicians
# General Practice/ Primary Care Physician/ Public Health/ Occupational Health and Safety
# Addiction Specialist
# Interventional cardiology
# Cancer,laparoscopic surgery,cosmetic surgery
# Adult Rheumatology - Internal Medicine
# Nutritional Medicine, Family Medicine
# Hema
# General Pediatrician
# IM Nephro
# integrative
# MSU Mississippi State University
# kik
# Emergency Medicine, Family Medicine
# Infectious
# Obstetrics and Gynecoloy
# Sdj
# ORTHOPAEDIC SURGERY
# Opthalmologist
# Marine engineer
# Small Animal
# Clinical Optometry
# Diabetes
# Pediatric Pulmonology
# Pulmonary Internal Med
# IM - Adult Cardiology / Interventional Cardiology
# Orthodontic, Implantology, Esthetic Dentistry
# N/a
# Spine & Orthopedics
# Bdjsp
# Household
# RMT
# finane
# General orthopedics
# Primary Health Care/Occupational Health
# ENT / Otolaryngology - Head and Neck Surgery
# Clinical Psychology
# Pediatrics- nephrology
# Real Estate
# Being Me
# Otorhinolaryngology (Ears, Nose, Throat), Head and Neck Surgery
# Integrative Anti-Aging and Regenerative / Functional Medicine / TCM Acupuncture
# psychiatry
# Internal Medicine - Adult Cardiology - Peripheral Vascular Medicine
# pulmonology
# otorhinolaryngology
# ORAL SURGERY
# Hospital Administration
# GYNECOLOGUE
# Dog & Cat Medicine & Surgery
# OTORHINOLARYNGOLOGY, HEAD AND NECK SURGERY ( ENT )
# Trisha Reyes
# Occupational and Industrial Medicine
# Laboratory
# 3
# PHD Clinical Psychology on going
# General Pediatrics  Pediatric Infectious Diseases
# Pediatric, Allergies
# Occupational Medicine & Public Health
# GI
# Dermatology and Aesthetics
# Orthopaedic Surgery - Hand Specialist
# General Dentistry and Orthodontics
# Internal Medicine - Cardiology; Non-invasive Cardiology; Nuclear Cardiology & Advanced Cardiovascular Imaging
# OPTOMETRY
# Adult Cardio
# Diagnostic And Interventional Radiology
# Plastic, Aesthetic and Reconstructive Surgey
# Podiatrist
# Orthopedic Surgery -Sports Medicine -Trauma -MusculoSkeletal Pain & Ultrasound
# tester
# Not Sure
# Major in accountancy
# Famed
# NEUROLOGY
# Ears
# Haematology
# FAMILY PHYSICIAN
# Orthopaedic Surgery And General Orthopedics
# Organ Transplant and Vascular Surgery, General Surgery
# MAIN SPECIALTY
# Registered Pharmacist
# Internal Medicine-Diabetologist
# Internal Medicine - Gastroenterology, Therapeutic Endoscopy, ERCP
# geriartic
# Adult Infectious Diseases/ Internal Medicine
# Internal Medicine, Diplomate
# Adult and Pediatric Urology
# OSH
# Hospitalist
# respiridone (risgin) and Rivotril
# Y
# Dr. Anna Mitzi Matela
# Primary Health Care
# Internal Medicine-Gastroenterology & Liver Diseases
# Adult and Occupational Medicine
# General Pediatric
# Contact Lens, Refraction
# OB gyne
# Infectious desease doctor
# Intenal Medicine
# Vnc
# Inoflox
# Insect Borne Diseases
# Urologist - Urology and Laser Surgery
# Allergy and Clinical Immunology
# any
# internal medecine
# Endoc
# IM-Infectious Diseases
# Plastic,Aesthetic, Reconstructive & Burns
# Internal Medicine -Adult Disease Specialist
# OB - Gyn
# RURAL HEALTH PHYSICIAN
# PULMONARY
# Occupational Medicine, Aesthetic Medicine
# engineering
# Pyschiatry
# Diabetology
# Gastrointorology
# Pediatric -Adolescent Medicine
# Infectious Disease Doctor
# Otorhinolarygology - Head & Neck Surgery
# Ob/Gyn
# I
# CS
# Xray
# PEDIATRICS - ALLERGOLOGY AND IMMUNOLOGY
# Bshshshs
# PreHospital
# Internal medicine
# INTERNAL MEDICINE- INFECTIOUS DISEASES
# Internal Medicinw
# Primary Care Physician/ General Medicine
# General Dentistry, Orthodontics, & Implants
# Otorhinolaryngology- Head And Neck
# Nephrology (Kidney Disease) and Internal Medicine
# Valerie Ann  Valdez
# Adult Infectious Diseases
# Ear Nose Throat, Head and Neck Surgery
# Medical Oncologist
# Medicie
# Caregiver
# Rheumatoid
# Medecine
# General Practice
# NEPHROLOGY ( Kidney Diseases and Dialysis)
# rehab
# Pathologic and Aesthetic Dermatology with Venereology
# MS.
# ORTHO
# Pscyhology
# Pedia, Family Medicine
# Geriatric Medicine-Diabetology
# Pediatrics-Neonatology
# Endocronology
# Cosmetic Dentistry
# Cardiovascular Surgery
# Primary Care / General Medicine
# Telepsychology
# Occupational Health Medicine
# Clinical and Anatomic Pathology
# Internal Medicine and Primary Care
# Med-student
# Gonzalez
# FN
# Clinical Tropical Medicine
# gp
# sccs
# Pediatrics, Toxicology
# Infectious desease
# Otorhinolaryngology Head & Neck Surgery
# General Practitioner / Occupational Health Physician
# Need new prescription
# Cardio Vascular & Thoracic Surgery
# Aesthetic Medicine & Cosmetic Surgery
# Orrhopedic trauma
# Endi
# Family Medicine , Primary Care
# moon light
# Healthcare Provider
# nursing services
# Main Specialty
# inter medicone
# INTERNAL MEDICINE Resident
# Hemothologist
# General Surgery/ Occupatonal Medicine
# Internal medicine Cardiology
# diabetologist
# Ginecologa Obstetra
# Ginecóloga Obstetra
# Ob gyn ultrasound
# Obstertics and Gynecology
# Cancer Treatment
# No
# medical
# Cosmetic Surgeon
# Health Communication
# NONE
# Pharmacist
# Ortho spine
# Non
# General Practitioner/ Military Doctor
# ms.colen laureano
# OB gynie
# Ears Nose Throat-Head and Neck Surgery
# Lifestyle Medicine & Plant-Based Chef
# Pedriatrics
# Wala
# Clinical Nutrition/Nutrition Support
# Nuclear Medicine and Theranostics / PET-CT
# OB-Gyn-
# Biomimetic Restorative Dentistry
# User
# Gastro Pedia
# infectiology
# MBA
# asfasfsaf
# awf
# asdf
# Shejsjj
# Early Childhood Development | Primary Care
# ...
# Emed
# General Ent
# Primary Care Physician - General Practitioner
# Internal Medicine / Adult Nephrology
# Ears, Nose, Throat - Head and Neck Surgery (ENT-HNS)
# General Medicine and Neurology
# ear
# Internal Medicine, HIV Primary Care, Transgender Health
# Gygghh
# Orthopedic Surgery and Sports Medicine
# Obstetrics & Gynecologist
# ophthalmologist
# Eye Care Specialist
# General Practitioner - Occupational Health
# Orthodontics, Prosthodontics and Cosmetic Dentistry
# Internal Medicine Pulmonary Diseases
# Hshhs
# Ears, nose, throat- head and neck surgery
# Oral Surgery - Dental Implants
# Nutrition and Dietetics
# General Cosmetic Surgery and Occupational Health
# FAmily
# Holistic Medicine & Nutrition
# General Practitioners
# Diplomate in Internal Medicine | Adult Diseases
# Primary Care, Family Medicine, Occupational and Industrial Medicine
# Otorhinolaryngology (ENT) Head & Neck Surgery
# Allen Marquez
# Teeth
# Primare Care Physician
# Pediatrics/ Occupational Health and Safety
# ENT, Family Medicine
# 131375
# Occupational Health Physican
# Chiro
# Cosmetic
# Adult And Pediatric Emergency Medicine
# General physician/ General Surgery
# Orthopedic & Spine Surgery
# Prevention
# Azarraga
#  General Practitioner
# Orthopedis Surgery
# FireFighter
# Nephrology,Internal Medicine
# Breast CA
# IM - Nephrology
# Aesthetic Derma and Anti Aging Medicien
# Rehabilitation  Medicine
# Allergy, Asthma, General and Reproductive Immunology
# Cancer Surgery
# Orthopedic surgey
# Physical Medicine and Rehabilitation | Physiatrist
# Thoracic, Cardiac And Vascular Surgery
# anesthesiology
# Information technology
# Pediatrics, General Medicine, Primary Care
# General Practitioner / Certified Family Physician
# Davao del Norte Hospital - IGACOS Zone
# Internal Medicine - Diabetes Specialist
# General Surgery, General Medicine
# Fellow, Obstetrical and Gynecological society
# General Medicine - Pediatrics
# Internal Medicine, Adult Disease Specialist
# Xisis
# ENDOCRINOLOGY
# General and Laparoscopic Surgery
# General Medicine- Anesthesiologist
# Obstetrician/Gynecologist
# Craniodontic TMJ, Airway and Dental Sleep Medicine
# General Dentistry, Orthodontics, Oral Surgery, Endodontics, Pediatric Dentistry
# Vision Therapy/ Behavioral Optometry
# Aesthetic Physician
# hepa
# Otorhinolaryngology (Ear, Nose, & Throat [ENT]) - Head & Neck Surgery
# General Dentistry,Orthodontics,Cosmetic Dentistry, Surgery, Pediatrics
# Internal Medicine - Critical Care Medicine
# General Physician, 1st Year - Practice-Based Family Medicine Resident
# Primary Care/General Practice
# Krizelda Timbang
# Fellow in Internal Medicine
# Religion
# Alicia M. Gonzalez
# Lymphatic Drainage massage therapist
# General Medicine; Aesthetics And Dermatology
# Teaching
# General Practice,  General Medicine
# General Medicine, Lifestyle Medicine
# Small animal medicine and surgery
# General Medicin, Anesthesiology
# Skip
# Otolaryngology-Head and Neck Surgery (ENT-HNS)
# Family Medicine (Primary Care practice in Mental Health, Hypertension, Diabetes, Sleep)
# General Medicine, Occupational Health and Safety
# Not A Doctor
# OBSTETRICS & GYNECOLOGY
# Ob-Gynecology / Ultrasound Subspecialist
# General Medicine, Primary Care, Occupational & Industrial Medicine
# Internal Medicine- Pulmonology
# Board Certified Pediatrician
# Primary Care/General Medicine/Family Medicine/Preventive Medicine
# PULMONOLOGY AND ADULT MEDICINE/ INTERNAL MEDICINE
# Emergency, Critical Care, Internal Medicine
# Plastic, Reconstructive, and Aesthetic Surgery
# General Practitioner, Professor
# DCFM
# INTERNAL MEDICINE ADULT CARDIOLOGY
# Pulmonology - Internal Medicine
# Adult Pulmonology
# Rehabilitation Medicine, SpineCor Pediatric and Adult Brace Provider
# Internal Medicine General Medicine
# Neurology/Parkinsons disease and movement disorders
# Internal medicine, general practice
# guycvujb
# Endocrin
# Internal medicine, infectious disease & tropical medicine
# Cardio
# General surgery, Minimally Invasive surgery
# Allergy , Asthma, Immunology
# Massage
# General Practitioner - Adult Medicine
# Edocrinology
# Behavioral & Developmental
# Occupational Health, Primary Care, Public Health
# Encology
# Pediatric Dentistry, Esthetic Dentistry, General Dentistry
# ??
# Internal Medicine, Occupational Health
# General Physician / 09559301258
# General Medicine/Lifestyle Medicine
# General Medicine, Primary care, Occupational Health Physician
# Surgical Resident
# Primary Healthcare Physician
# General Medicine (Adult and Pediatric)
# Obstetrician & Gynecologist
# Pulmonary and Neurology
# Developmental Pedia
# Adult Cardiology -Internal Medicine
# Psychosocial Counseling, Psychological Assessment, Mental Health
# secretary
# initial psychological assessment, consulting, counseling and psychotherapy
# hhh
# qqq
# general physician, primary care
# Hemodialysis Doctoe
# GENERAL MEDICINE (Adults and Children Diseases)
# General Physician
# Occupational Health Physician
# Internal Medicine-Adult Cardiology
# Occupational Medicine and Hypertension Specialist
# Occupational Health Medicine / General Medicine
# Pre-natal
# General Medicine, Sport Injury Prevention and Therapy
# Pain Medicine (pain management)
# COSMETICS, ORTHODONTICS, GENERAL
# Cancer Surgery and General Surgery
# Ophthalmology | Lifestyle Medicine
# Internal Medicine (Adult Diseases)
# Companion animal medicine
# dfghdfjh
# Hemodialysis Center
# 515828
# Internal medicine-diabetes, thyroid and metabolism
# OBSTETRICIAN AND GYNECOLOGIST
# General/ Emergency
# Family Mericine
# Obgyne and Infertility
# Alaxan
# General physician
# Eye
# Endocrinology
# General Medicine, 1 year experience in Primary Health Care
# Medical certificate
# General Medicine and Occupational Medicine
# General/Adult Psychiatry
# General dentistry
# Otorhinolaryngology Head and Neck Surgery
# Psychiatry Resident
# Industrial Engineering
# Internal Medicine (Adult Disease Specialist)
# Ear Nose Throat, Head and Neck Surgery
# Advanced Laparoscopic Surgery/ General Surgery
# Medico Legal
# Tech support
# Ears, Nose Throat - Head & Neck Surgery
# Internal/Adult Medicine
# General/Cancer Surgery
# General Medicine
# Internal Medicine
# Pulmonology and Critical Care Medicine
# Internal medicine, General Medicine
# Internal Medicine: General Medicine
# Aesthetician
# Skin Care
# Derma1
# Onco
# Anesthesiology, General Practitioner
# Cardiologist
# General Medicine - Adult and Pedia
# General Medicine, Obstetrics & Gynecology, Public Health, Primary Care
# General Practitioner, Primary Care & Occupational Medicine
# Primary Care Physician (Adult & Children Diseases)
# General  Practitioner
# Internal Medicine, Adult Diseases
# Internal medicine, gyne
# Mental Health  & Psychotherapy
# Pediatrics and General Practitioner
# OBSTETRICIAN gynecologic
# OBSTETRICIAN AND GYNAECOLOGY
# Internal Medicine - Diabetes, Thyroid and General Endocrinology,
# Family Medicine and Occupational Medicine
# Ocology
# Internal Medicine - Infectious and Tropical Diseases
# DERMATOLOGY, PEDIATRICS,
# General PEDIATRICS
# Advanced Orthopaedic Trauma
# ONCOLOGY
# gynecology
# Nutrition Therapy
# Sugery
# Internal Medicine Cardiology
# Internal Medicine - Adult Cardiology - Vascular Specialist
# General  Practice
# Poisoning, Snake Bites, Cobra Envenomation, Clinical Toxicology, HAZMAT Life Support, Family Medicine, Primary Medicine
# Dermatology and Venereology
# GENERAL AND LAPAROSCOPIC SURGERY
# Home Physical Therapist
# to motivate
# Speech Pathology
# General Dentistry, Oral Surgery, Periodontics, Dental Implantology
# Family Medicine and Occupational Medicine; Technical Health and Safety, Life and Mental Health Coach, Process Improvement, Workplace Legal Health Industry Expert, Accredited OSH Consultant & Speaker
# W
# Sugar
# Developmental Pediatrician
# fertility
# Ears, Nose and Throat
# Oncology -gynecology
# gen
# Twst
# Aesthetic & Pathologic Dermatology
# Genetics
# Primary Care Physician, General Practitioner, General Medicine
# Obstetrics and Gynecology (OB-GYN)
# Small Animal
# Obstetrics And Gynecologist
# Engine Department
# depression
# Foot and Ankle Surgeon
# General Medicine, Primary Care, General Practitioner
# Obstetrics and Gynecology (Ob-Gyn)
# Asksbdkdnd
# TMJ MANAGEMENT, LASER DENTISTRY
# General Practitioner, Public Health, Primary Care, TB and Drug-Resistant TB
# pediatric nurse
# Shshaha
# OBSTETRICIAN GYNECOLOGY
# Family and Community Medicine, General Practice, Adult and Child Medicine
# General Medicine, Aesthetic Medicine
# INTERNAL MEDICINE-NEPHROLOGY
# Dentist
# PATIENT
# General Family Medicine
# Dermatologist (Skin)
# Network Security and Network Infrastructure
# Hematology
# k
# Comprehensive Ophthalmology: Cataract, Eye Diseases, Microsurgery and LASER
# General Medicine, Primary Care, Family Medicine, Lifestyle Medicine
# Integrative and Lifestyle Medicine
# Small animal practice
# General Pediatrics & Pediatric Hematology
# Ear, Nose and Throat- Head and Neck Surgery
# Cosmetic Dentistry, Orthodontics, Surgery, General Dentistry
# OBGYN, Family Medicine
# Pediatric Dentistry and Orthodontics
# Pedia Derma
# Mental Health Counseling
# Cbc
# Pediatric Gastroenterology, Hepatology, and Nutrition
# Secretary medical
# My medication
# Sickness
# General Medicine / General Practitioner
# Bible Translation
# Gastro
# PRIMARY CARE MEDICINE
# OB-gyn
# Pediatrics, Pediatric Cardiology
# Ears Nose Throat - Head and Neck Surgery
# Clinical and Cosmetic Dermatology / Occupational MD - General Med
# Internal Medicine - Cardiology/Cardio-Oncology
# General Medicine/Primary Care Physician
# Production
# aesthetic
# Dog bite vaccine
# Counseling, Positive Psychology, Strengths Coaching
# Counseling
# Medical abstract
# nejdhdjdjdh
# Internal Medicine | Nephrology
# Developmental pedia
# Adult Specialist
# no
# Family Medicine, Lifestyle Medicine
# General Phycians
# CARDIOVASCULAR
# General Surgery and Minimally Invasive Surgery
# Obstetrician - Gynecologist, OBGYN
# Aesthetics and General Medicine
# cardiologist
# Adult & Pediatric Optometry, DPA Certified
# Community and family medicine
# For check up
# Therapeutic sessions to help clients cope with Stress, Burnout, Interpersonal conflict,  Anxiety, Mood disorders, Grief, Low self-efficacy, Self-harm behavior etc.
# Cosmetic Surgeon, Regenerative Specialist, Functional and Aesthetic Gyneologist, Obstetrician
# Check up
# Refraction
# Obstetrics and Gynecology (OBGYN), Reproductive Endocrinology & Infertility
# General Adult And Child Medicine
# Laboratory Medicine
# Obsterics- Gynecology
# Eye Doctor
# General Surgery/Laparoscopic Surgery/Cancer Surgery
# Internal Medicine / Adult Cardiology - Interventional Cardiology
# Otolaryngology
# Family Medicne
# Machinis
# Generap Psychiatrist
# Jehejejej
# Nonde
# education
# Dentistry, General Medicine
# Obstetician
# Developmental pediatrician
# Marlon Arcegono
# Ears,nose,throat-Head and Neck Surgery
# Internal Medicine and Medical Oncology
# General Practitioner; Pediatrics
# Psychotherapy, Counseling, Psychology
# Ophthalmology SPCMC
# Wrong Entry
# General Medicine, Occupational Health Medicine, Lifestyle Medicine
# Obstetrician And Gynecologist
# Fermont Base
# Ear, Nose,Throat-Head and Neck Surgery
# Orthodontics, Cosmetic Dentistry, Periodontics, Pedodontics, Surgery, General Dentistry
# surgical
# Internal Medicine- Adult Nephrology
# IM trained
# TMJ-Craniodontics
# Ears,Nose,Throat-Head And Neck Surgery
# Adult & Child Allergy, Asthma & Clinical Immunology
# General and Laparoscoopic Surgery
# Occupational Medicine/General Medicine
# Family mesicine
# General Dentistry, Orthodontics, Esthetic Dentistry
# Diet & Nutrition
# INTERNAL MEDICINE - PULMONOLOGY
# Juan Rafael
# Partner Visa
# Family Medicine  OH Pysician
# medical physicists
# General Dernatology
# General Physician / 09368241461
# Clinical and Cosmetic Dermatology
# Looking For A Fertility Doctor
# E N T
# Registered Psychologist
# Medical Oncology & Internal Medicine
# GRIEF COUNSELING,  MARITAL/COUPLE/FAMILY COUNSELING
# Psychotherapy, Counseling
# Licensed and Registered Psychologist
# Obstetrian and Gynecologist
# Diabetes doctor
# fdd
# Speech And Language Pathology
# Periodontics and Dental Implants
# Obstetric Gynecologist
# Neurologist/Sleep Medicine
# General physician/ primary skin health physician / dermatology
# Internal Medicine-Gastroenterology
# Inject anti rabies
# Mental Health / Addiction Medicine / Medico-Legal / General Medicine (Primary Care)
# Family Medicine (Adult and Children Diseases)
# GENERAL  MEDICINE
# Nephrologu
# Dialysis
# Enternal Medicine
# Counseling/Psychotherapy through Expressive Arts for children (4-12), adolescents (13-17), and young adults (18-30)
# Counseling and Psychotherapy
# Dental medicine
# OB-Gynecologist
# vessel
# Obstetrics and gynecology
#  aesthetics
# Hand and Orthopedic Surgery
# Otolaryngologist - Ear, Nose, throat, Head and Neck
# All
# Doctor of Veterinary Medicine
# Depression and Anxiety
# Psychometrician & Psychologist
# Counseling, Coaching
# Facial
# Foot
# Intergumentary
# Electrophysiology/ Cardiologist
# MEDICAL DOCTOR & BREAST SPECIALIST RADIOLOGIST
# Gennielene G Lazaro
# Gennielene G Lazaro
# Internal Medicine, Gastroenterology, Therapeutic Endoscopy
# Primary Care Physician
# Orthopedic Surgeon
# OB Gynecology
# ENT-Head & Neck Specialist
# Small animals
# jsjsjsja
# Doctor Of Optometry
# General Practice, Public Health
# Cardiothoracic Surgery
# Workplace Psychology
# Psychological Counseling and Therapy
# Internal Medicine, Aesthetic Medicine
# Exotic
# General Medicine Practitioner
# General Medicine and Occupational Health
# Hormone Health, Women's Health, Functional Nutrition, Gut Issues
# Preventive Medicine & Public Health
# General Medicine, Primary Care.
# Interal Medicine,Gastroenterology,Digestive Endoscopy
# Clinical Psychology | Psychotherapy | Psychological Testing | Mental Health Speaker
# Obygyn
# Primary Care & General Medicine
# LLala
# Primary Physician
# General Medicine, lifestyle medicine, occupational health medicine
# Internal Medicine / Adult Disease Specialist
# Genera Dentist
# Immunologys
# Primary Care, Public Health
# FAMILY /GENERAL MEDICINE
# Vaginal bleeding
# Dentistry, Implant Dentistry, Orthodontics, Cosmetic Dentistry, Oral Surgery, Prosthodontics, Endodontic Dentistry
# General, Laparoscopic, Cancer Surgery
# Psychiatry, Mental Health
# Dentistry, Implantology, Oral Surgery, Orthodontics, Endodontics, Prosthodontics, Cosmetic Dentistry
# Neurology and Psychiatry
# Occupational & Industrial Medicine, Hypertension Specialist, Primary Care
# Ortho/ surgery
# NEPHROLOGY
# Counseling Psychology, Mental Health Counseling
# Medical Acupuncture
# ENT (Otorhinolaryngology) - Head and Neck Surgery
# General Medicine | Adult Neurology Resident
# Orthopedic bone
# Bbb
# Sales
# General Medicine Primary Care, Health and Wellness Nutrition, Weight Loss Management
# Benoza
# Psychometrician
# General Dentistry, Oral Surgery, Orthodontics
# Tele Consult
# Counseling & Psychotherapy
# OM
# Clinical, Aesthetic & Surgical Dermatology
# Counseling/ Psychotherapy
# Medical assistant
# Primary care
# Primay Care Phycisian
# Dental Implants
# Mental Health Services
# Counseling
# Lung
# Jajan
# General Medicine, Nutrition and Dietetics
# Physical therapy
# Otolaryngology-Head and Neck Surgery (Ears, Nose, Throat)
# General Obstetrics And Gynecology
# General Medical Practioner
# General Medicine, Primary Care, Rehabilitation Physical Therapy
# MD, General Practitioner
# General Practitioner
# Primary Care Physician
# Laboratory aide
# Snsnd
# Aesthetic, Plastic, and Reconstructive Surgery
# AESTHETIC NURSE
# Occupational Medicine and General Practice
# Primary Care and General Medicine
# Animal bite
# Primary Care, Family Medicine/Integrative Medicine
#
# GENERAL ORTHOPEDICS AND TRAUMATOLOGY
# Small Animal Medicine
# Orthopaedic and Spine Surgery
# Psychology, Psychotherapy, EAP, Counselling
# Neurology (Adult)
# Psychometrician, General Physician
# Depression, Anxiety
# Yu
# OtoRhinoLaryngology-Head & Neck Surgery
# Counseling, Stress Management, Anxiety Management, Depression, Behavioral Modification, Assessment
# Oral Surgery and Esthetics
# Internal Medicine- Neurology
# FOLLOW UP
# jana
# Occupational Health, Anesthesiology
# hdh
# Joshua Bacolod
# BONE ALIGNMENT
# INTERNAL MEDICINE CARDIOLOGY
# Plastic, Aesthetic and Reconstructive Surgery
# enen
# Integrative Medicine/Lifestyle Medicine
# Recovery-Oriented Addiction Medicine
# Psychiatry and Internal Medicine
# Brain and Spine Surgery
# General Medicine, General Pediatrics
# Guidance and Counseling
# Ear, Nose, Throat (ORL) - Head and Neck Surgery
# Emergency Medicine/ Occupational Medicine
# Eye Refraction, Optical Services and Products
# Cosmetic Surgery, Aesthetic and Anti-Aging Medicine
# Ob Gynecology
# Urology
# js
# Bone alignment therapy
# Healot Biomekaniks
# Allergist

# %% [markdown]
# Show columns

# %%
appointments.head(100)
# Out:
#                                    pxid                          clinicid  \
# 76059  FE4A5D5A20EC492D2FC691F126A568AB  3B8D83483189887A2F1A39D690463A8F
# 76061  E6BC8E80685AA4A239617F196F12A0C3  3B8D83483189887A2F1A39D690463A8F
# 76063  E430B3D3AEED550612FFDBD0F2F94112  3B8D83483189887A2F1A39D690463A8F
# 76064  E6BC8E80685AA4A239617F196F12A0C3  3B8D83483189887A2F1A39D690463A8F
# 76069  41E3F930274A7704305EE197F3434877  3B8D83483189887A2F1A39D690463A8F
# ...                                 ...                               ...
# 76554  0173144A9589D9B631D1213CB68CD1F3  287ABB19DA8AADBD118443E92685853E
# 76560  A4B7F2DEFAB485D3E823EC2E2887CE8B  287ABB19DA8AADBD118443E92685853E
# 76561  17F29BDC62FF6C1E3EADA946F41BD78C  287ABB19DA8AADBD118443E92685853E
# 76562  E181F837A7F5701CC5537781E94D3537  287ABB19DA8AADBD118443E92685853E
# 76563  276BBC91182D1B6924ACDA861C146B07  287ABB19DA8AADBD118443E92685853E
#
#                                doctorid                            apptid  \
# 76059  ACB3A881C7CE9ABCAE0CE8C99C86A906  04BC9218E072BEEFEBEE9C97B78A35C9
# 76061  ACB3A881C7CE9ABCAE0CE8C99C86A906  F2335AAFB7EE079C7E7306591057C0C9
# 76063  ACB3A881C7CE9ABCAE0CE8C99C86A906  B2C83D6DE89A88C5CD9EA1FD5FC00602
# 76064  ACB3A881C7CE9ABCAE0CE8C99C86A906  DA4023B5A8C3F1BD540EA82552F21134
# 76069  ACB3A881C7CE9ABCAE0CE8C99C86A906  C805F7992F18E33AB85CEBD572680943
# ...                                 ...                               ...
# 76554  ACB3A881C7CE9ABCAE0CE8C99C86A906  24BBEF21D8B8E1F63BF9D95D22C52854
# 76560  ACB3A881C7CE9ABCAE0CE8C99C86A906  9ECD6AD001663BFF8259BF04932B287E
# 76561  ACB3A881C7CE9ABCAE0CE8C99C86A906  1F61DE829ECDBAA4E09FB099781C47E8
# 76562  ACB3A881C7CE9ABCAE0CE8C99C86A906  39250431EA8C0D7384AD60C9534AB386
# 76563  ACB3A881C7CE9ABCAE0CE8C99C86A906  2CB9F1DD9BBB54D6AF9CE2607772934C
#
#          status                     TimeQueued            QueueDate  \
# 76059    Queued  2020-06-22 05:11:38.247000000  2020-07-02 16:00:00
# 76061    Queued  2020-06-26 04:51:16.403000000  2020-07-12 16:00:00
# 76063    Queued  2020-07-13 07:00:50.127000000  2020-07-19 16:00:00
# 76064    Queued  2020-07-13 06:07:13.537000000  2020-07-28 16:00:00
# 76069    Queued  2020-06-26 05:54:35.117000000  2020-09-27 16:00:00
# ...         ...                            ...                  ...
# 76554  Complete  2020-11-19 04:26:13.893000000  2020-11-19 16:00:00
# 76560  Complete  2020-11-23 23:37:40.580000000  2020-11-23 16:00:00
# 76561  Complete  2020-11-20 02:25:35.360000000  2020-11-23 16:00:00
# 76562  Complete  2020-11-22 10:37:27.423000000  2020-11-23 16:00:00
# 76563  Complete  2020-11-23 23:46:59.510000000  2020-11-23 16:00:00
#
#                            StartTime                        EndTime  \
# 76059  2020-07-02 17:00:38.073000000  2020-07-02 17:15:38.073000000
# 76061  2020-07-12 17:00:15.833000000  2020-07-12 17:15:15.833000000
# 76063  2020-07-20 05:00:49.687000000  2020-07-20 05:15:49.687000000
# 76064  2020-07-29 05:00:13.133000000  2020-07-29 05:15:13.133000000
# 76069  2020-09-27 17:00:34.917000000  2020-09-27 17:15:34.917000000
# ...                              ...                            ...
# 76554            2020-11-20 01:30:00            2020-11-20 01:45:00
# 76560            2020-11-24 03:15:00            2020-11-24 03:30:00
# 76561            2020-11-24 01:00:00            2020-11-24 01:15:00
# 76562            2020-11-24 01:45:00            2020-11-24 02:00:00
# 76563            2020-11-24 02:45:00            2020-11-24 03:00:00
#
#                type Virtual
# 76059  Consultation     NaN
# 76061  Consultation     NaN
# 76063  Consultation     NaN
# 76064  Consultation     NaN
# 76069  Consultation     NaN
# ...             ...     ...
# 76554  Consultation   False
# 76560  Consultation    True
# 76561  Consultation    True
# 76562  Consultation   False
# 76563  Consultation    True
#
# [100 rows x 11 columns]

# %%
#clinics.head(100)

# %%
#doctors.head(100)

# %%
#px.head(100)

# %% [markdown]
# ### Check if there are duplicated rows

# %%
# Duplicate rows in Doctors
duplicate_doctors = doctors.duplicated()
doctors[duplicate_doctors]
# Out:
# Empty DataFrame
# Columns: [doctorid, mainspecialty, age]
# Index: []

# %%
# Duplicate rows in Px
duplicate_px = px.duplicated(keep=False)
px[duplicate_px]

px.drop_duplicates(inplace=True)
px.shape
px.info
# Out:
# <bound method DataFrame.info of                                      pxid  age  gender
# 0        5A1718EC380AFE6BE24D63EE78CDA043  NaN  FEMALE
# 1        C0FC9D6384C7F579F1048A461C298B8C    8  FEMALE
# 2        FB0C4098E2F7FD0BC3865382242E7034    2  FEMALE
# 3        EB3C1CBD5A2AC52C69BE0B90C5E149A7   54    MALE
# 4        92C92C2EB4B51FBB3CD354165BA5F027   67  FEMALE
# ...                                   ...  ...     ...
# 6507808  9D8045364678C651016538B78784720E   56    MALE
# 6507809  BCC86927CB7F687624859D5B7C9AB8B6   60    MALE
# 6507810  2890460EE1FD505905A0A55834EBDC06   17  FEMALE
# 6507811  3989D63FA4DD7C54911AA085CB7CF38A   62    MALE
# 6507812  80E396F35668298FED90AD2278A6D28D   46  FEMALE
#
# [5512484 rows x 3 columns]>

# %%
# Duplicate rows in Clinics
duplicate_clinics = clinics.duplicated()
clinics[duplicate_clinics]
# Out:
# Empty DataFrame
# Columns: [clinicid, hospitalname, IsHospital, City, Province, RegionName]
# Index: []

# %%
# Duplicate rows in Appointments
duplicate_appointments = appointments.duplicated()
appointments[duplicate_appointments]
# Out:
# Empty DataFrame
# Columns: [pxid, clinicid, doctorid, apptid, status, TimeQueued, QueueDate, StartTime, EndTime, type, Virtual]
# Index: []

# %% [markdown]
# # Cleaning Doctors

# %%
print("Nulls in doctors:")
for column in ['doctorid', 'mainspecialty', 'age']:
    print(f"{column} nulls = {doctors[column].isnull().sum()}")
# Out:
# Nulls in doctors:
# doctorid nulls = 0
# mainspecialty nulls = 32849
# age nulls = 39996

# %%
doctors.shape
# Out:
# (60024, 3)

# %%
# Initialize null doctor's age to zero so we can convert the data type from DOUBLE to INT
doctors['age'].fillna(0, inplace=True)
doctors[doctors['age'] == 0]
# Out:
#                                doctorid         mainspecialty  age
# 24     ED3D2C21991E3BEF5E069713AF9FA6CA                   NaN  0.0
# 28     EC8956637A99787BD197EACD77ACCE5E                   NaN  0.0
# 31     65B9EEA6E1CC6BB9F0CD2A47751A186F                   NaN  0.0
# 33     A97DA629B098B75C294DFFDC3E463904                   NaN  0.0
# 38     7F6FFAA6BB0B408017B62254211691B5                   NaN  0.0
# ...                                 ...                   ...  ...
# 60016  3DC09677E0FDB539A31D497C4FB25F20  general practitioner  0.0
# 60017  39D96AC1450B2D517807DC8A94B26C17         Ophthalmology  0.0
# 60020  4473D870B5E31FAA40D2C45E1FF6DC27                   NaN  0.0
# 60021  A4F554EB2C0934E7FDE2511E8C1573BA                   NaN  0.0
# 60022  E540A361D93D37A33BB2F55D43DA79D9  General Practitioner  0.0
#
# [39996 rows x 3 columns]

# %%
# Convert data type to INT
doctors['age'] = doctors['age'].astype('int32')

# %%
x = (doctors['age'] < 21) & (doctors['age'] != 0)
y = (doctors['age'] > 120) & (doctors['age'] != 0)

# Exclude rows where age is less than 0 or greater than 100
doctors = doctors[~(x | y)]
doctors.shape
# Out:
# (59997, 3)

# %% [markdown]
# # Cleaning Patients

# %%
print("Nulls in Patient:")
for column in ['pxid', 'age', 'gender']:
    print(f"{column} nulls = {px[column].isnull().sum()}")
# Out:
# Nulls in Patient:
# pxid nulls = 0
# age nulls = 9999
# gender nulls = 0

# %% [markdown]
# Gender column there is a row that has the value of gender
# We dropped that row

# %%
print(px.gender.value_counts())

data1 = px[px['gender'] == 'gender']
print(data1)

data = px[px['pxid'] == 'pxid']
print(data)

px.drop(px[px['gender'] == 'gender'].index, inplace=True)
data1 = px[px['gender'] == 'gender']
# Out:
# FEMALE    3095509
# MALE      2416974
# gender          1
# Name: gender, dtype: int64
#         pxid  age  gender
# 995328  pxid  age  gender
#         pxid  age  gender
# 995328  pxid  age  gender

# %%
px['age'].isna().value_counts()
# Out:
# False    5502484
# True        9999
# Name: age, dtype: int64

# %% [markdown]
# Drop NaN ages

# %%
px.dropna(subset=['age'], inplace=True)

# %%
px['age'] = px['age'].astype('int32')

# %%
px['age'].isna().value_counts()
# Out:
# False    5502484
# Name: age, dtype: int64

# %% [markdown]
# Drop Unrealistic ages

# %%
x = px.age < 0
y = px.age > 120

print(x.sum())
print(y.sum())
# Out:
# 1003
# 11335

# %%
# Assuming 'px' is the name of your DataFrame
x = px['age'] < 0
y = px['age'] > 120

# Exclude rows where age is less than 0 or greater than 100
px = px[~(x | y)]
px.shape
# Out:
# (5490146, 3)

# %% [markdown]
# # Cleaning Clinics

# %% [markdown]
# Since when hospital name is null is when ishospital is false then no need to remove the nulls

# %%
print("Nulls in clinics:")
for column in ['clinicid', 'hospitalname', 'IsHospital', 'City', 'Province', 'RegionName']:
    print(f"{column} nulls = {clinics[column].isnull().sum()}")
# Out:
# Nulls in clinics:
# clinicid nulls = 0
# hospitalname nulls = 36424
# IsHospital nulls = 0
# City nulls = 0
# Province nulls = 0
# RegionName nulls = 0

# %%
clinics[clinics.IsHospital == False].isnull().sum()
# Out:
# clinicid            0
# hospitalname    36424
# IsHospital          0
# City                0
# Province            0
# RegionName          0
# dtype: int64

# %%
clinics.dtypes
# Out:
# clinicid        object
# hospitalname    object
# IsHospital        bool
# City            object
# Province        object
# RegionName      object
# dtype: object

# %%
print(clinics.hospitalname.isnull().sum())
print(clinics[clinics['IsHospital'] == False].hospitalname.isnull().sum())
print(clinics[clinics['IsHospital'] == False].shape)
# if the clinic is not a hospital is it should not have a hospital name
# Out:
# 36424
# 36424
# (36424, 6)

# %% [markdown]
# # Cleaning Appointments

# %%
print("Null in appointments")
for column in ['pxid', 'clinicid', 'doctorid', 'apptid', 'status', 'TimeQueued', 'QueueDate', 'StartTime', 'EndTime', 'type', 'Virtual']:
    print(f"{column} nulls = {appointments[column].isnull().sum()}")
# Out:
# Null in appointments
# pxid nulls = 0
# clinicid nulls = 0
# doctorid nulls = 0
# apptid nulls = 0
# status nulls = 0
# TimeQueued nulls = 0
# QueueDate nulls = 0
# StartTime nulls = 116532
# EndTime nulls = 259988
# type nulls = 0
# Virtual nulls = 190136

# %%
appCols = ['pxid', 'clinicid', 'doctorid', 'apptid', 'status', 'TimeQueued',
       'QueueDate', 'StartTime', 'EndTime', 'type', 'Virtual']
for col in appCols:
    null_count = appointments[col].isnull().sum()
    print(f"Column '{col}': {null_count} null values")
# Out:
# Column 'pxid': 0 null values
# Column 'clinicid': 0 null values
# Column 'doctorid': 0 null values
# Column 'apptid': 0 null values
# Column 'status': 0 null values
# Column 'TimeQueued': 0 null values
# Column 'QueueDate': 0 null values
# Column 'StartTime': 116532 null values
# Column 'EndTime': 259988 null values
# Column 'type': 0 null values
# Column 'Virtual': 190136 null values

# %% [markdown]
# Before covid virtual appointments were not common or were not available at all. That is why no virtual column till recently. Therefore all null values in virtual should be false.

# %%
appointments['Virtual'] = appointments['Virtual'].fillna(False)

# %%
appointments['Virtual'].isnull().sum()
# Out:
# 0

# %%
appointments.status.value_counts()
# Out:
# Queued      179638
# Complete    135259
# Cancel        2258
# Serving       1544
# NoShow        1008
# Skip           433
# Name: status, dtype: int64

# %%
print(appointments[appointments['status'] == 'Complete'].StartTime.isnull().sum())
print(appointments[appointments['status'] == 'Queued'].StartTime.isnull().sum())
print(appointments[appointments['status'] == 'Cancel'].StartTime.isnull().sum())
print(appointments[appointments['status'] == 'Serving'].StartTime.isnull().sum())
print(appointments[appointments['status'] == 'NoShow'].StartTime.isnull().sum())
print(appointments[appointments['status'] == 'Skip'].StartTime.isnull().sum())
print("\n")

print(appointments[appointments['status'] == 'Complete'].EndTime.isnull().sum())
print(appointments[appointments['status'] == 'Queued'].EndTime.isnull().sum())
print(appointments[appointments['status'] == 'Cancel'].EndTime.isnull().sum())
print(appointments[appointments['status'] == 'Serving'].EndTime.isnull().sum())
print(appointments[appointments['status'] == 'NoShow'].EndTime.isnull().sum())
print(appointments[appointments['status'] == 'Skip'].EndTime.isnull().sum())
# Out:
# 88045
# 27650
# 396
# 327
# 58
# 56
#
#
# 101250
# 157897
# 398
# 329
# 58
# 56

# %%
# change appointments timequeued and queuedate to datetime

appointments['TimeQueued'] = pd.to_datetime(appointments['TimeQueued'])
appointments['QueueDate'] = pd.to_datetime(appointments['QueueDate'])
appointments['StartTime'] = pd.to_datetime(appointments['StartTime'])
appointments['EndTime'] = pd.to_datetime(appointments['EndTime'])

# %% [markdown]
# # After cleaning each table remove appointments that are not in the dimesion tables (may need rewording)

# %%
# remove appointments that are not in pxid table
print(appointments.shape)
appointments = appointments[appointments['pxid'].isin(px['pxid'])]

# remove appointments that are not in the clinics table
print(appointments.shape)
appointments = appointments[appointments['clinicid'].isin(clinics['clinicid'])]
print(appointments.shape)

# remove appointments that are not in the doctors table
print(appointments.shape)
appointments = appointments[appointments['doctorid'].isin(doctors['doctorid'])]
print(appointments.shape)
# Out:
# (320140, 11)
# (319854, 11)
# (319854, 11)
# (319854, 11)
# (319854, 11)

# %% [markdown]
# # EDA?

# %%
print(appointments['status'].value_counts(), "\n")
print(appointments['type'].value_counts(), "\n")
print(appointments['Virtual'].value_counts(), "\n")
print(doctors['mainspecialty'].value_counts(), "\n")
print(doctors['age'].value_counts(), "\n")
print(px['gender'].value_counts(), "\n")
print(px['age'].value_counts(), "\n")
# Out:
# Queued      179582
# Complete    135064
# Cancel        2231
# Serving       1542
# NoShow        1002
# Skip           433
# Name: status, dtype: int64
#
# Consultation    319645
# Inpatient          209
# Name: type, dtype: int64
#
# False    314007
# True       5847
# Name: Virtual, dtype: int64
#
# Internal Medicine                        3808
# General Medicine                         2317
# Pediatrics                               1708
# Family Medicine                           893
# General Physician                         880
#                                          ...
# Marc                                        1
# Orthopaedics (Bone and Joint Surgery)       1
# Generalists                                 1
# Public Health, Pathology                    1
# Allergist                                   1
# Name: mainspecialty, Length: 3969, dtype: int64
#
# 0     39996
# 34     1215
# 35     1082
# 33      973
# 37      971
#       ...
# 21        1
# 22        1
# 84        1
# 79        1
# 85        1
# Name: age, Length: 71, dtype: int64
#
# FEMALE    3080715
# MALE      2409431
# Name: gender, dtype: int64
#
# 29     125362
# 54     125306
# 28     121702
# 31     120597
# 32     120355
#         ...
# 116        13
# 119        11
# 115         9
# 118         8
# 117         6
# Name: age, Length: 121, dtype: int64

# %%
print(appointments.shape)

#print(is_time_queued_less_than_queue_date)
#print(appointments[appointments['TimeQueued'] > appointments['QueueDate']].shape)

# change appointments timequeued and queuedate to datetime

# appointments['TimeQueued'] = pd.to_datetime(appointments['TimeQueued'])
# appointments['QueueDate'] = pd.to_datetime(appointments['QueueDate'])
#print(appointments.TimeQueued)
#print(appointments.QueueDate)
is_time_queued_less_than_queue_date = (appointments['TimeQueued'] < appointments['QueueDate']).count()
is_time_queued_before_queue_date = (appointments['TimeQueued'] < appointments['QueueDate']).count()
print(is_time_queued_before_queue_date)


print((appointments['TimeQueued'] > appointments['QueueDate']).sum())
print((appointments['TimeQueued'] < appointments['QueueDate']).sum())
print((appointments['TimeQueued'] == appointments['QueueDate']).sum())
#print((appointments['TimeQueued'] < appointments['QueueDate']).sum() + (appointments['TimeQueued'] > appointments['QueueDate']).sum())

print(appointments.iloc[1])
print(appointments.iloc[1]['TimeQueued'] < appointments.iloc[1]['QueueDate'])
# Out:
# (319854, 11)
# 319854
# 138832
# 61414
# 119608
# pxid          E6BC8E80685AA4A239617F196F12A0C3
# clinicid      3B8D83483189887A2F1A39D690463A8F
# doctorid      ACB3A881C7CE9ABCAE0CE8C99C86A906
# apptid        F2335AAFB7EE079C7E7306591057C0C9
# status                                  Queued
# TimeQueued          2020-06-26 04:51:16.403000
# QueueDate                  2020-07-12 16:00:00
# StartTime           2020-07-12 17:00:15.833000
# EndTime             2020-07-12 17:15:15.833000
# type                              Consultation
# Virtual                                  False
# Name: 76061, dtype: object
# True

# %% [markdown]
# # Uploading to MySQL

# %%
load_dotenv()

db_host = os.getenv('DB_HOST')
db_password = os.getenv('DB_PASSWORD')
db_schema = os.getenv('DB_SCHEMA')

print("DB Host:", db_host)
print("DB Password:", db_password)
print("DB Schema:", db_schema)

engine_path = 'mysql+pymysql://root:' + db_password + '@' + db_host + '/' + db_schema
print(engine_path)
# Out:
# DB Host: localhost
# DB Password: Shbbapagquqo123
# DB Schema: mco1
# mysql+pymysql://root:Shbbapagquqo123@localhost/mco1

# %%
engine = create_engine(engine_path)

# %%
appointments.to_sql('appointments', con=engine, if_exists='replace', index=False)
# Out:
# 319854

# %%
doctors.dtypes
# Out:
# doctorid         object
# mainspecialty    object
# age               int32
# dtype: object

# %%
appointments.doctorid
# Out:
# 76059      ACB3A881C7CE9ABCAE0CE8C99C86A906
# 76061      ACB3A881C7CE9ABCAE0CE8C99C86A906
# 76063      ACB3A881C7CE9ABCAE0CE8C99C86A906
# 76064      ACB3A881C7CE9ABCAE0CE8C99C86A906
# 76069      ACB3A881C7CE9ABCAE0CE8C99C86A906
#                          ...
# 9602481    F7F07E7DAB09533BC71247A5B29A7373
# 9602483    F7F07E7DAB09533BC71247A5B29A7373
# 9602484    F7F07E7DAB09533BC71247A5B29A7373
# 9602492    F7F07E7DAB09533BC71247A5B29A7373
# 9602502    F7F07E7DAB09533BC71247A5B29A7373
# Name: doctorid, Length: 319854, dtype: object

# %%
doctors.to_sql('doctors', con=engine, if_exists='replace', index=False)
# Out:
# 59997

# %%
appointments[appointments.doctorid == 'doctors_idx']
# Out:
# Empty DataFrame
# Columns: [pxid, clinicid, doctorid, apptid, status, TimeQueued, QueueDate, StartTime, EndTime, type, Virtual]
# Index: []

# %%
px.to_sql('px', con=engine, if_exists='replace', index=False)
# Out:
# 5490146

# %%
clinics.columns
# Out:
# Index(['clinicid', 'hospitalname', 'IsHospital', 'City', 'Province',
#        'RegionName'],
#       dtype='object')

# %%
clinics.to_sql('clinics', con=engine, if_exists='replace', index=False)
# Out:
# 53962
